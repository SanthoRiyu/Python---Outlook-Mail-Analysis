# %%
import win32com.client
import win32com
import os
import sys

# %%
#outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")
outlook = win32com.client.Dispatch("Outlook.Application").Session.Stores
accounts= win32com.client.Dispatch("Outlook.Application").Session.Accounts;

# %%
for account in outlook:
     print(account.DisplayName)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-18711dfd99f1> in <module>()
# ----> 1 for account in outlook:
#       2      print(account.DisplayName)
#
# TypeError: 'Stores' object is not iterable

# %%
def emailleri_al(folder):
    messages = folder.Items
    a=len(messages)
    if a>0:
        for message2 in messages:
             try:
                sender = message2.Subject
                if sender != "":
                    print(sender)
             except:
                print("Error")
                print(account.DeliveryStore.DisplayName)
                pass

             try:
                message2.Save
                message2.Close(0)
             except:
                 pass

# %%
for account in accounts:
    global inbox
    inbox = outlook.Folders(account.DeliveryStore.DisplayName)
    print("****Account Name**********************************")
    print(account.DisplayName)
    print("***************************************************")
    folders = inbox.Folders

    for folder in folders:
        print("****Folder Name**********************************")
        print(folder)
        print("*************************************************")
#         emailleri_al(folder)
        a = len(folder.folders)

        if a>0 :
            global z
            z = outlook.Folders(account.DeliveryStore.DisplayName).Folders(folder.name)
            x = z.Folders
            for y in x:
                if y.name == 'batch':
                    emailleri_al(y)
                    print("****Folder Name**********************************")
                    print("..."+y.name)
                    print("*************************************************")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-a0efe3f70917> in <module>()
# ----> 1 for account in accounts:
#       2     global inbox
#       3     inbox = outlook.Folders(account.DeliveryStore.DisplayName)
#       4     print("****Account Name**********************************")
#       5     print(account.DisplayName)
#
# TypeError: 'Accounts' object is not iterable

# %%
import win32com.client
import os
outlook=win32com.client.Dispatch("Outlook.Application").GetNameSpace("MAPI")
inbox=outlook.Folders("SD_SD-Drift") #Inbox default index value is 6
message=inbox.Items
message2=message.GetLast()
# subject=message2.Subject
body=message2.body
date=message2.senton.date()   
# sender=message2.Sender
# attachments=message2.Attachments
# print(subject)
# print(body)
# print(sender)
# print(attachments.count)
print(date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b0ebfa4090a5> in <module>()
#       1 import win32com.client
#       2 import os
# ----> 3 outlook=win32com.client.Dispatch("Outlook.Application").GetNameSpace("MAPI")
#       4 inbox=outlook.Folders("SD_SD-Drift") #Inbox default index value is 6
#       5 message=inbox.Items
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in __getattr__(self, attr)
#     471                 args=self._prop_map_get_.get(attr)
#     472                 if args is None:
# --> 473                         raise AttributeError("'%s' object has no attribute '%s'" % (repr(self), attr))
#     474                 return self._ApplyTypes_(*args)
#     475
#
# AttributeError: '<win32com.gen_py.Microsoft Outlook 16.0 Object Library._Application instance at 0x1684399477984>' object has no attribute 'GetNameSpace'

# %%
import win32com.client

for stor in win32com.client.Dispatch("Outlook.Application").Session.Stores:
    print( stor.DisplayName)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-5c9ffade24e1> in <module>()
#       1 import win32com.client
#       2
# ----> 3 for stor in win32com.client.Dispatch("Outlook.Application").Session.Stores:
#       4     print( stor.DisplayName)
#
# TypeError: 'Stores' object is not iterable

# %%
outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")
folder = outlook.Folders("SD_SD-Drift")
inbox = folder.Folders("Inbox")
msg = inbox.Items

# %%
outlook=win32com.client.Dispatch("Outlook.Application").GetNameSpace("MAPI")


your_folder = outlook.Folders["SD_SD-Drift"].Folders['Inbox'].Folders['AftenVagt']
for message in your_folder.Items:
    print(message.Subject)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-522e5e4bb70d> in <module>()
# ----> 1 outlook=win32com.client.Dispatch("Outlook.Application").GetNameSpace("MAPI")
#       2
#       3
#       4 your_folder = outlook.Folders["SD_SD-Drift"].Folders['Inbox'].Folders['AftenVagt']
#       5 for message in your_folder.Items:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in __getattr__(self, attr)
#     471                 args=self._prop_map_get_.get(attr)
#     472                 if args is None:
# --> 473                         raise AttributeError("'%s' object has no attribute '%s'" % (repr(self), attr))
#     474                 return self._ApplyTypes_(*args)
#     475
#
# AttributeError: '<win32com.gen_py.Microsoft Outlook 16.0 Object Library._Application instance at 0x2224222653576>' object has no attribute 'GetNameSpace'

# %%
text1 = ["I am not in the list", "this is one #tag LRGCOPB this is ?another tag","Nattens korsler forsinkede - Alarm pp L0Z000 -2019-02-05","Using TWS-2019-02-08","LMD129/LMDKON -2019-02-15","RE: L2Z995 -904, copy pending -2019-02-28"]
for text in text1:
    for word in text.split():
        if word.startswith("L"):
            print (word)
# Out:
# LRGCOPB
# L0Z000
# LMD129/LMDKON
# L2Z995

# %%
import re
text = "LKDIBA,B,C,D,LSDI1A-F"
text_list = re.split(',|-', text)
base_txt = text_list[0]
for text1 in text_list:
    if len(text1)>1:
        print(text1)
    else:
        print(base_txt[:-1]+ text1)
# Out:
# LKDIBA
# LKDIBB
# LKDIBC
# LKDIBD
# LSDI1A
# LKDIBF

# %%
import win32com.client

search_string = 'Selvaraj'

outlook = win32com.client.gencache.EnsureDispatch('Outlook.Application')
gal = outlook.Session.GetGlobalAddressList()
entries = gal.AddressEntries
ae = entries[search_string]
email_address = None
if 'EX' == ae.Type:
    eu = ae.GetExchangeUser()
    email_address = eu.PrimarySmtpAddress
    
if 'SMTP' == ae.Type:
    email_address = ae.Address

print('Email address: ', email_address)

# https://docs.microsoft.com/en-us/office/vba/api/outlook.exchangeuser
# Out:
# Email address:  seminar@eg.dk

# %%
import win32com.client

o = win32com.client.gencache.EnsureDispatch("Outlook.Application")
ns = o.GetNamespace("MAPI")

adrLi = ns.AddressLists.Item("Global Address List")
contacts = adrLi.AddressEntries
numEntries = adrLi.AddressEntries.Count

nameAliasDict = {}

for i in contacts:
    name = i.Name
    alias = i.Address.split("=")[-1]
    nameAliasDict[alias] = name

print( "\nThe global address list contains",numEntries,"entries.")
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-77-a2c0ef1f4999> in <module>()
#       5
#       6 adrLi = ns.AddressLists.Item("Global Address List")
# ----> 7 contacts = adrLi.AddressEntries
#       8 numEntries = adrLi.AddressEntries.Count
#       9
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in __getattr__(self, attr)
#     472                 if args is None:
#     473                         raise AttributeError("'%s' object has no attribute '%s'" % (repr(self), attr))
# --> 474                 return self._ApplyTypes_(*args)
#     475
#     476         def __setattr__(self, attr, value):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     465         def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
#     466 		return self._get_good_object_(
# --> 467                         self._oleobj_.InvokeTypes(dispid, 0, wFlags, retType, argTypes, *args),
#     468 			user, resultCLSID)
#     469
#
# com_error: (-2147352567, 'Exception occurred.', (4096, 'Microsoft Outlook', 'The connection to Microsoft Exchange is unavailable. Outlook must be online or connected to complete this action.', None, 0, -2147221227), None)

# %%
import win32com.client

DEBUG = 0

class MSOutlook:
    def __init__(self):
        self.outlookFound = 0
        try:
            self.oOutlookApp = \
                win32com.client.gencache.EnsureDispatch("Outlook.Application")
            self.outlookFound = 1
        except:
            print ("MSOutlook: unable to load Outlook")
        
        self.records = []


    def loadContacts(self, keys=None):
        if not self.outlookFound:
            return

        # this should use more try/except blocks or nested blocks
        onMAPI = self.oOutlookApp.GetNamespace("MAPI")
        ofContacts = \
            onMAPI.GetDefaultFolder(win32com.client.constants.olFolderContacts)

        if DEBUG:
            print ("number of contacts:", len(ofContacts.Items))

        for oc in range(len(ofContacts.Items)):
            contact = ofContacts.Items.Item(oc + 1)
            if contact.Class == win32com.client.constants.olContact:
                if keys is None:
                    # if we were't give a set of keys to use
                    # then build up a list of keys that we will be
                    # able to process
                    # I didn't include fields of type time, though
                    # those could probably be interpreted
                    keys = []
                    for key in contact._prop_map_get_:
                        if isinstance(getattr(contact, key), (int, str, unicode)):
                            keys.append(key)
                    if DEBUG:
                        keys.sort()
                        print ("Fields\n======================================")
                        for key in keys:
                            print (key)
                record = {}
                for key in keys:
                    record[key] = getattr(contact, key)
                if DEBUG:
                    print (oc, record['FullName'])
                self.records.append(record)


if __name__ == '__main__':
    if DEBUG:
        print ("attempting to load Outlook")
    oOutlook = MSOutlook()
    # delayed check for Outlook on win32 box
    if not oOutlook.outlookFound:
        print ("Outlook not found")
        sys.exit(1)

    fields = ['FullName',
                'CompanyName', 
                'MailingAddressStreet',
                'MailingAddressCity', 
                'MailingAddressState', 
                'MailingAddressPostalCode',
                'HomeTelephoneNumber', 
                'BusinessTelephoneNumber', 
                'MobileTelephoneNumber',
                'Email1Address',
                'Body'
                ]

    if DEBUG:
        import time
        print ("loading records...")
        startTime = time.time()
    # you can either get all of the data fields
    # or just a specific set of fields which is much faster
    #oOutlook.loadContacts()
    oOutlook.loadContacts(fields)
    if DEBUG:
        print ("loading took %f seconds" % (time.time() - startTime))
    for outtwr in oOutlook.records:
        print ("Contact: %s" % outtwr)
#     print ("Number of contacts: %d" % len(oOutlook.records))
#     print ("Contact: %s" % oOutlook.records[0]['FullName'])
#     print ("Body:\n%s" % oOutlook.records[0]['Body'])
# Out:
# Contact: {'FullName': 'vijayalakshmi.selvaraj', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': 'vijayalakshmi.selvaraj@standardbank.co.za', 'Body': ''}
# Contact: {'FullName': 'Nithya Poland', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+48\xa0579\xa0322\xa0732', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'W Prathish', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+44 7459 857180', 'BusinessTelephoneNumber': '+91 7397 252 670', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Kalai Poland', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+48\xa0579\xa0322\xa0739', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Little India Warsaw Domi', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '228436738', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Vignesh Poland', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+48\xa0729\xa0665\xa0769', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Kalai Mama', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+91 91768 55856', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Vamsi Poland', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '739635180', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Charlotte DBA JN Data', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+4521598799', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Lars EG', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+4540840066', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Jn Data Operation', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+4563636410', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Maria Molberg', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+45 7260 1280', 'BusinessTelephoneNumber': '+45\xa040\xa015\xa088\xa095', 'MobileTelephoneNumber': '+45 40 15 88 95', 'Email1Address': 'mmolb@sd.dk', 'Body': ''}
# Contact: {'FullName': 'Jaya Murugan Epp', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+91 99526 50075', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Saravana Kumar Matrimony', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+971\xa052\xa0257\xa07085', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+91 99946 26707', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Monika Visa', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+48\xa022\xa0630\xa061\xa000', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+48 696 725 102', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Balaji Poland', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '729\xa0310\xa0199', 'BusinessTelephoneNumber': '+91\xa081223\xa051467', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Satheesh Lnt Deputy Head', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '579115278', 'BusinessTelephoneNumber': '+91\xa096869\xa097869', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Jalpesh Poland', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '739583715', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Mohanraj Avadi', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+91 99419 50985', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Gopalakrishnan BSS', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+91 98848 92479', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Gopalakrishnan BSS', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+91 98848 92479', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Marcin Poland Head', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '507 009 810', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Ramesh Varan', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+91 99402 24595', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Ramesh Varan', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+91 99402 24595', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Vamsi2', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+48 739 635 141', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Goibibo', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '', 'BusinessTelephoneNumber': '', 'MobileTelephoneNumber': '+91 92130 25552', 'Email1Address': '', 'Body': ''}
# Contact: {'FullName': 'Suri', 'CompanyName': '', 'MailingAddressStreet': '', 'MailingAddressCity': '', 'MailingAddressState': '', 'MailingAddressPostalCode': '', 'HomeTelephoneNumber': '+45 71 52 72 38', 'BusinessTelephoneNumber': '+91 90007 83502', 'MobileTelephoneNumber': '91 86677 40460', 'Email1Address': '', 'Body': ''}

# %%
import win32com.client

o = win32com.client.gencache.EnsureDispatch("Outlook.Application")
ns = o.GetNamespace("MAPI")

adrLi = ns.AddressLists.Item("Global Address List")
contacts = adrLi.AddressEntries
numEntries = adrLi.AddressEntries.Count

nameAliasDict = {}

for i in contacts:
    name = i.Name
    alias = i.Address.split("=")[-1]
    nameAliasDict[alias] = name

print ("\nThe global address list contains",numEntries,"entries.")
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-63-788fb840459d> in <module>()
#       5
#       6 adrLi = ns.AddressLists.Item("Global Address List")
# ----> 7 contacts = adrLi.AddressEntries
#       8 numEntries = adrLi.AddressEntries.Count
#       9
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in __getattr__(self, attr)
#     472                 if args is None:
#     473                         raise AttributeError("'%s' object has no attribute '%s'" % (repr(self), attr))
# --> 474                 return self._ApplyTypes_(*args)
#     475
#     476         def __setattr__(self, attr, value):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     465         def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
#     466 		return self._get_good_object_(
# --> 467                         self._oleobj_.InvokeTypes(dispid, 0, wFlags, retType, argTypes, *args),
#     468 			user, resultCLSID)
#     469
#
# com_error: (-2147352567, 'Exception occurred.', (4096, 'Microsoft Outlook', 'The connection to Microsoft Exchange is unavailable. Outlook must be online or connected to complete this action.', None, 0, -2147221227), None)

# %%
import win32com.client

o = win32com.client.gencache.EnsureDispatch("Outlook.Application")
ns = o.GetNamespace("MAPI")

adrLi = ns.AddressLists.Item("Global Address List")
contacts = adrLi.AddressEntries
numEntries = adrLi.AddressEntries.Count

nameAliasDict = {}

for i in contacts:
    name = i.Name
    alias = i.Address.split("=")[-1]
    nameAliasDict[alias] = name

print ("\nThe global address list contains",numEntries,"entries.")
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-72-788fb840459d> in <module>()
#       5
#       6 adrLi = ns.AddressLists.Item("Global Address List")
# ----> 7 contacts = adrLi.AddressEntries
#       8 numEntries = adrLi.AddressEntries.Count
#       9
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in __getattr__(self, attr)
#     472                 if args is None:
#     473                         raise AttributeError("'%s' object has no attribute '%s'" % (repr(self), attr))
# --> 474                 return self._ApplyTypes_(*args)
#     475
#     476         def __setattr__(self, attr, value):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args)
#     465         def _ApplyTypes_(self, dispid, wFlags, retType, argTypes, user, resultCLSID, *args):
#     466 		return self._get_good_object_(
# --> 467                         self._oleobj_.InvokeTypes(dispid, 0, wFlags, retType, argTypes, *args),
#     468 			user, resultCLSID)
#     469
#
# com_error: (-2147352567, 'Exception occurred.', (4096, 'Microsoft Outlook', 'The connection to Microsoft Exchange is unavailable. Outlook must be online or connected to complete this action.', None, 0, -2147221227), None)

# %%
import win32com.client
import os
output_list = []
import pickle

def emailleri_al(folder):
    messages = folder.Items
    a=len(messages)
    if a>0:
        for message2 in messages:
             try:
                Sub = message2.Subject
                date1 = message2.senton.date()

                if Sub != "":
                    for word in Sub.split():
                        if word.startswith("L"):
                            if "/" in word:
                                word_sep = word.split('/')
                                for word_ser in word_sep:
                                    output_list.append(word_ser + ' - ' + str(date1))

                            elif ',' in word:
                                text_list = word.split(',')
                                base_txt = text_list[0]
                                for text1 in text_list:
                                    if len(text1)>1:
                                        output_list.append(text1 + ' - ' + str(date1))
                                    else:
                                        output_list.append(base_txt[:-1]+ text1 + ' - ' + str(date1))

                            else:
                                output_list.append(word + ' - ' + str(date1))
             except:
                print("Error")
                pass
             try:
                message2.Save
                message2.Close(0)
             except:
                 pass
    pickle.dump(set(output_list), open('Pickled_set_job.p',"wb"))

outlook=win32com.client.Dispatch("Outlook.Application").GetNameSpace("MAPI")
global inbox
inbox=outlook.Folders("SD_SD-Drift")
folders = inbox.Folders

for folder in folders:
    # print(type(folder.name))
    if folder.name == 'Inbox':
        print('Inbox reached')
        emailleri_al(folder)

    # a = len(folder.folders)
    # if a>0 :
    #     global z
    #     z = outlook.Folders("SD_SD-Drift").Folders(folder.name)
    #     x = z.Folders
    #     for y in x:
    #         if y.name == 'Inbox':
    #             print('Inbox reached')
                # emailleri_al(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-3927b5af91a2> in <module>()
#      42     pickle.dump(set(output_list), open('Pickled_set_job.p',"wb"))
#      43
# ---> 44 outlook=win32com.client.Dispatch("Outlook.Application").GetNameSpace("MAPI")
#      45 global inbox
#      46 inbox=outlook.Folders("SD_SD-Drift")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\win32com\client\__init__.py in __getattr__(self, attr)
#     471                 args=self._prop_map_get_.get(attr)
#     472                 if args is None:
# --> 473                         raise AttributeError("'%s' object has no attribute '%s'" % (repr(self), attr))
#     474                 return self._ApplyTypes_(*args)
#     475
#
# AttributeError: '<win32com.gen_py.Microsoft Outlook 16.0 Object Library._Application instance at 0x2224219156776>' object has no attribute 'GetNameSpace'

# %%
import codecs
import tempfile

import win32api
import win32com.client
constants = win32com.client.constants

session = win32com.client.Dispatch ("MAPI.Session")
session.Logon ()

filename = tempfile.mktemp (suffix=".csv")
print( "Writing to", filename)
f = codecs.open (filename, "w", "latin-1")
try:
  address_lists = session.AddressLists
  gal = address_lists.Item ("Global Address List")
  addresses = gal.AddressEntries
  for i in range (addresses.Count):
    entry = addresses.Item (i + 1)
    if entry.DisplayType == constants.CdoUser:
      name = entry.Name
      smtp = entry.Fields[0x39FE001E]
      f.write ('"%s","%s"\n' % (name, smtp))
      print (name)
finally:
  f.close ()

session.Logoff ()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-1-6d6d2c96ec2f> in <module>()
#       6 constants = win32com.client.constants
#       7
# ----> 8 session = win32com.client.Dispatch ("MAPI.Session")
#       9 session.Logon ()
#      10
#
# C:\Users\xxkem\AppData\Local\Continuum\anaconda3\envs\py2\lib\site-packages\win32com\client\__init__.pyc in Dispatch(dispatch, userName, resultCLSID, typeinfo, UnicodeToString, clsctx)
#      93   """
#      94   assert UnicodeToString is None, "this is deprecated and will go away"
# ---> 95   dispatch, userName = dynamic._GetGoodDispatchAndUserName(dispatch,userName,clsctx)
#      96   return __WrapDispatch(dispatch, userName, resultCLSID, typeinfo, clsctx=clsctx)
#      97
#
# C:\Users\xxkem\AppData\Local\Continuum\anaconda3\envs\py2\lib\site-packages\win32com\client\dynamic.pyc in _GetGoodDispatchAndUserName(IDispatch, userName, clsctx)
#     112         else:
#     113                 userName = str(userName)
# --> 114         return (_GetGoodDispatch(IDispatch, clsctx), userName)
#     115
#     116 def _GetDescInvokeType(entry, invoke_type):
#
# C:\Users\xxkem\AppData\Local\Continuum\anaconda3\envs\py2\lib\site-packages\win32com\client\dynamic.pyc in _GetGoodDispatch(IDispatch, clsctx)
#      89                         IDispatch = pythoncom.connect(IDispatch)
#      90                 except pythoncom.ole_error:
# ---> 91                         IDispatch = pythoncom.CoCreateInstance(IDispatch, None, clsctx, pythoncom.IID_IDispatch)
#      92         else:
#      93                 # may already be a wrapped class.
#
# com_error: (-2147221005, 'Invalid class string', None, None)

# %%
import win32com.client

search_string = "santhosh"

outlook = win32com.client.gencache.EnsureDispatch('Outlook.Application')
gal = outlook.Session.GetGlobalAddressList()
entries = gal.AddressEntries
ae = entries[search_string]
email_address = None

if 'EX' == ae.Type:
    eu = ae.GetExchangeUser()
    email_address = eu.PrimarySmtpAddress

if 'SMTP' == ae.Type:
    email_address = ae.Address

print('Email address: ', email_address)
# Out:
# Email address:  xxkem@sd.dk

# %%
import win32com.client

o = win32com.client.gencache.EnsureDispatch("Outlook.Application")
ns = o.GetNamespace("MAPI")

adrLi = ns.AddressLists.Item("Global Address List")
contacts = adrLi.AddressEntries
numEntries = adrLi.AddressEntries.Count

nameAliasDict = {}

for i in contacts:
    name = i.Name
    alias = i.Address.split("=")[-1]
    nameAliasDict[alias] = name

print ("\nThe global address list contains",numEntries,"entries.")
print(nameAliasDict)
# Out:
# The global address list contains 6671 entries.
# {'0a11ed882bcf4be7836f82d661f94d96-Mineopgaver': '!Mine opgaver', '3bc2076053ae4402a3ef693b2e3da502-Innovationb': '#Innovationboard', 'ffe0eaec9eed487db39709b7df5e9af4-netdevelopm': '.NET development', 'a2613407e0aa426eaf8f965cb055692e-030228megaf': '030228 Megaflis', '807433c8bb724a63a7fffc20a710b6f1-030921Solla': '030921 Solland', '5af632af2eed4d1b89bb45e82bdcbf2e-031110edael': '031110 EDA Elektro', '8c20924fbe2949e4acbb6633ffdab378-031759Partn': '031759 Partnermed', '12f990a0e5a747d7844e924d6a09dfbf-1egdi_a59b3': '1egdi', 'ef5dc9b7115f41ffb1f5fa073af3e0b5-henve_a749d': '1henve', '10a991155366400eace5e787cdb98533-2018marketi': '2018 marketing film', '6d81ef26afc648ccb76a79cc60bae6c2-2019_SALESM': '2019_SALES&MARKETING', '5af2bf0a665e4b108cc7a9de4006f785-2dp_deaa8af': '2DP', '8cb11fcea97c49168252a0921a7f423d-3db3b4c4-51': '2DPoint', '8f24f8480315420285181fe002519c56-29f51cb0-bc': '2DPoint-Gausdal', '7f1ffb27a7ad459c9f10a55e7a1ade25-365': '365', '77af87576c6a4c52893bc77546761082-3CRetailpro': '3C Retail projekt', '0fd1ab62960a47eab6ab93e0f119d83f-3navikonapo': '3N Aviko Napoleon', 'fbdb8fd0183348b09453a42c99283bff-570kt-st_be': '570 KT-Øst', '3db623c1f7b54c8fbddf8a7bd0d672bf-6514egdk_ff': '6514@eg.dk', '106dc4f9fa554a8b9a0a2a205aefb897-28_f085a478': 'Å', '999d6f8a0dad4c1995d22fbb6d1603aa-AabenraaKom': 'Aabenraa Kommune udbud af økonomi-, debitor-, løn-, vagtplan- og indkøbssystem', '48f01bd4c9cd4841b95e86df8dd2b962-aalborgdkhe': 'Aalborg DK Healthcare', 'e51a137270e94725a09498b6009d0fb0-Aalborg Mee': 'Aalborg, DXC (8), ext', 'usereb720c39': 'Aalborg, Grøn (8), ext', 'f27b5869567744c8af4f1d30b71ba6c5-Aalborg Mee': 'Aalborg, Orange (8), ext', 'b572f1f4a4764aee9f8f5943b1dbe699-AalesundPro': 'Aalesund Protective Wear', '0bc83178960044d88944c178bd8273d1-aarhusdkhea': 'Aarhus DK Healthcare', '77078888d845448ebb1a2626d4a55447-Aarhus meet': 'Aarhus, 0th left, meeting 00 (6), ext', 'user26a5a454': 'Aarhus, 0th left, meeting 01 (6), ext', 'user528b3bf0': 'Aarhus, 0th left, meeting 02 (12), ext', 'userabcf4b70': 'Aarhus, 0th left, meeting 03 (12), ext', 'user517378dd': 'Aarhus, 0th left, meeting 04 (12), ext', 'user7331f141': 'Aarhus, 0th left, meeting 05 (6), ext', 'user83b49a67': 'Aarhus, 0th left, meeting 06 (6), ext', 'user9bf8abcb': 'Aarhus, 0th left, meeting 07 (6), ext', 'userf0f25cee': 'Aarhus, 0th left, meeting 08 (12), ext', 'user05830aae': 'Aarhus, 0th left, meeting 09 (6), ext', 'userf5c634aa': 'Aarhus, 0th left, meeting 10 (18), ext', 'user5a9957a0': 'Aarhus, 0th left, meeting 11 (12), ext', 'userb7068084': 'Aarhus, 0th left, meeting 12 (30), ext', '6e9bd19137dd467e81349f7da4a3af75-Aarhus meet': 'Aarhus, 0th left, meeting 15 (12), ext', '4cdd9df4b2e547ba9d52fa0a9fbc67fe-Aarhus meet': 'Aarhus, 0th right, meeting 01 (6), int', '8aa624720b10470c86e230bfa9461a95-Aarhus meet': 'Aarhus, 0th right, meeting 02 (6), int', 'c2a9445812a643bfaf38ab077c3b7268-Aarhus meet': 'Aarhus, 0th right, meeting 03 (6), int', '6e18b305a2bc4491b7602cd6f0052955-Aarhus meet': 'Aarhus, 0th right, meeting 04 (4), int', 'c2e6a5bdf6844d38bdff0e2990885188-Aarhus meet': 'Aarhus, 0th right, meeting 05 (6), int', 'ef533c6b6b9a45f7886e1edea81d874f-Aarhus meet': 'Aarhus, 0th right, meeting 06 (4), int', '048b3e0a2ac64174a1cd9c7f7f5017b0-Aarhus meet': 'Aarhus, 1st left, meeting 01 (2), int', 'a313f3d85fb4412ca0abdc30e40cd3f4-Aarhus meet': 'Aarhus, 1st left, meeting 02 (8), int', '0d6005d4c19f47f39a41dfaa2bc6c969-Aarhus meet': 'Aarhus, 1st left, meeting 03 (4), int', '16afb22a9b56468995e47c11fbea8820-Aarhus meet': 'Aarhus, 1st left, meeting 05 (6), int', 'f8c04aea149a42d58c306320751619ef-Aarhus meet': 'Aarhus, 1st left, meeting 06 (6), int', 'f277dc65d5714a649a0a15942a7dd59a-Aarhus meet': 'Aarhus, 1st right, meeting 01 (6), int', '6f938db0c98644dbb91b71a6fcdc9f60-Aarhus meet': 'Aarhus, 1st right, meeting 02 (6), int', '1823a63aa3d64ff59c9886123da5186c-Aarhus meet': 'Aarhus, 1st right, meeting 03 (8), int', '590be6ceb9d44b369f8287c632310af8-Aarhus meet': 'Aarhus, 1 ...

# %%
import win32com.client

search_string = "santhosh"

outlook = win32com.client.gencache.EnsureDispatch('Outlook.Application')
gal = outlook.Session.GetGlobalAddressList()
entries = gal.AddressEntries
ae = entries[search_string]
email_address = None

if 'EX' == ae.Type:
    eu = ae.GetExchangeUser()
    email_address = eu.PrimarySmtpAddress

if 'SMTP' == ae.Type:
    email_address = ae.Address

print('Email address: ', email_address)

# %%
import win32com.client

o = win32com.client.gencache.EnsureDispatch("Outlook.Application")
ns = o.GetNamespace("MAPI")

adrLi = ns.AddressLists.Item("Global Address List")
contacts = adrLi.AddressEntries
numEntries = adrLi.AddressEntries.Count

nameAliasDict = {}

 for i in contacts:
    name = i.Name
    alias = i.Address.split("=")[-1]
    nameAliasDict[alias] = name

print ("\nThe global address list contains",numEntries,"entries.")

# %%
from __future__ import print_function
import win32com.client

search_string = 'Brian Kjær'

outlook = win32com.client.gencache.EnsureDispatch('Outlook.Application')
recipient = outlook.Session.CreateRecipient(search_string)
recipient.Resolve()
print('Resolved OK: ', recipient.Resolved)
print('Is it a sendable? (address): ', recipient.Sendable)
print('Name: ', recipient.Name)

ae = recipient.AddressEntry
email_address = None

if 'EX' == ae.Type:
    eu = ae.GetExchangeUser()
    email_address = eu.PrimarySmtpAddress
    alias = eu.Alias
if 'SMTP' == ae.Type:
    email_address = ae.Address

print('Email address: ', email_address)
print('Alias: ', alias)
# Out:
# Resolved OK:  True
# Is it a sendable? (address):  True
# Name:  Brian Kjær
# Email address:  bkjer@eg.dk
# Alias:  bkjer

# %%
import win32com.client

o = win32com.client.gencache.EnsureDispatch("Outlook.Application")
ns = o.GetNamespace("MAPI")

adrLi = ns.AddressLists.Item("Global Address List")
contacts = adrLi.AddressEntries
numEntries = adrLi.AddressEntries.Count

f1 = open('contact_list.txt','w')
for i in contacts:
    name = i.Name
    print(str(name.encode("utf-8")),file=f1)
#     f1.write(name.encode("utf-8")+'\n')
f1.close()

# %%
f2 = open('contact_list.txt')
data = f2.readlines()
for data1 in data:
    tes = data1[1:]
    print(tes.encode('utf-8'))
# Out:
# b"'!Mine opgaver'\n"
# b"'#Innovationboard'\n"
# b"'.NET development'\n"
# b"'030228 Megaflis'\n"
# b"'030921 Solland'\n"
# b"'031110 EDA Elektro'\n"
# b"'031759 Partnermed'\n"
# b"'1egdi'\n"
# b"'1henve'\n"
# b"'2018 marketing film'\n"
# b"'2019_SALES&MARKETING'\n"
# b"'2DP'\n"
# b"'2DPoint'\n"
# b"'2DPoint-Gausdal'\n"
# b"'365'\n"
# b"'3C Retail projekt'\n"
# b"'3N Aviko Napoleon'\n"
# b"'570 KT-\\xc3\\x98st'\n"
# b"'6514@eg.dk'\n"
# b"'\\xc3\\x85'\n"
# b"'Aabenraa Kommune udbud af \\xc3\\xb8konomi-, debitor-, l\\xc3\\xb8n-, vagtplan- og indk\\xc3\\xb8bssystem'\n"
# b"'Aalborg DK Healthcare'\n"
# b"'Aalborg, DXC (8), ext'\n"
# b"'Aalborg, Gr\\xc3\\xb8n (8), ext'\n"
# b"'Aalborg, Orange (8), ext'\n"
# b"'Aalesund Protective Wear'\n"
# b"'Aarhus DK Healthcare'\n"
# b"'Aarhus, 0th left, meeting 00 (6), ext'\n"
# b"'Aarhus, 0th left, meeting 01 (6), ext'\n"
# b"'Aarhus, 0th left, meeting 02 (12), ext'\n"
# b"'Aarhus, 0th left, meeting 03 (12), ext'\n"
# b"'Aarhus, 0th left, meeting 04 (12), ext'\n"
# b"'Aarhus, 0th left, meeting 05 (6), ext'\n"
# b"'Aarhus, 0th left, meeting 06 (6), ext'\n"
# b"'Aarhus, 0th left, meeting 07 (6), ext'\n"
# b"'Aarhus, 0th left, meeting 08 (12), ext'\n"
# b"'Aarhus, 0th left, meeting 09 (6), ext'\n"
# b"'Aarhus, 0th left, meeting 10 (18), ext'\n"
# b"'Aarhus, 0th left, meeting 11 (12), ext'\n"
# b"'Aarhus, 0th left, meeting 12 (30), ext'\n"
# b"'Aarhus, 0th left, meeting 15 (12), ext'\n"
# b"'Aarhus, 0th right, meeting 01 (6), int'\n"
# b"'Aarhus, 0th right, meeting 02 (6), int'\n"
# b"'Aarhus, 0th right, meeting 03 (6), int'\n"
# b"'Aarhus, 0th right, meeting 04 (4), int'\n"
# b"'Aarhus, 0th right, meeting 05 (6), int'\n"
# b"'Aarhus, 0th right, meeting 06 (4), int'\n"
# b"'Aarhus, 1st left, meeting 01 (2), int'\n"
# b"'Aarhus, 1st left, meeting 02 (8), int'\n"
# b"'Aarhus, 1st left, meeting 03 (4), int'\n"
# b"'Aarhus, 1st left, meeting 05 (6), int'\n"
# b"'Aarhus, 1st left, meeting 06 (6), int'\n"
# b"'Aarhus, 1st right, meeting 01 (6), int'\n"
# b"'Aarhus, 1st right, meeting 02 (6), int'\n"
# b"'Aarhus, 1st right, meeting 03 (8), int'\n"
# b"'Aarhus, 1st right, meeting 05 (4), int'\n"
# b"'Aarhus, 2nd left, meeting 01 (6), int'\n"
# b"'Aarhus, 2nd left, meeting 02 (6), int'\n"
# b"'Aarhus, 2nd left, meeting 04 (6), int'\n"
# b"'Aarhus, 2nd left, meeting 05 (6), int'\n"
# b"'Aarhus, 2nd left, meeting 06 (6), int'\n"
# b"'Aarhus, 2nd right, meeting 01 (6), int'\n"
# b"'Aarhus, 2nd right, meeting 02 (7), int'\n"
# b"'Aarhus, 2nd right, meeting 03 (7), int'\n"
# b"'Aarhus, 2nd right, meeting 04 (4), int'\n"
# b"'Aarhus, 2nd right, meeting 05 (6), int'\n"
# b"'Aarhus, 2nd right, meeting 06 (6), int'\n"
# b"'Aarhus, Canteen (200), ext'\n"
# b"'Aarhus, Kursuslokale (12), (bookes via kursus@eg.dk)'\n"
# b"'AArsafslutning'\n"
# b"'Aase Andersen'\n"
# b"'abc'\n"
# b"'Abdul Karim Yassin'\n"
# b"'ABRAM Test Site'\n"
# b"'Accoutplaner'\n"
# b"'ACL_DIV_700_BUS_765_ProjektData_Projekter_924500DWH_Modify'\n"
# b"'ACL_eg_sd_lon@eg.dk_Access'\n"
# b"'ACL_eg_sd_lon@eg.dk_Access_sendas'\n"
# b"'ACS@ctek.dk'\n"
# b"'Actions fra Strategy Reviews'\n"
# b"'Adam Dziewiecki'\n"
# b"'Adam Lilienberg'\n"
# b"'Adam Prze\\xc5\\xbadziecki'\n"
# b"'Adam William Engsig'\n"
# b"'Aditya Bargisen Bante'\n"
# b"'Administration DK - Aalborg'\n"
# b"'Administration DK - \\xc3\\x85rhus'\n"
# b"'Administration DK - Ballerup'\n"
# b"'Administration DK - Herning'\n"
# b"'Administration DK - Hj\\xc3\\xb8rring'\n"
# b"'Administration DK - Holb\\xc3\\xa6k'\n"
# b"'Administration DK - Kolding'\n"
# b"'Administration DK - Odense'\n"
# b"'Administration DK - Thisted'\n"
# b"'Administration NO - Bergen'\n"
# b"'Administration NO - Gj\\xc3\\xb8vik'\n"
# b"'Administration NO - Molde'\n"
# b"'Administration NO - Oslo'\n"
# b"'Administration NO - Sandefjord'\n"
# b"'Administration NO - Sandnes'\n"
# b"'Administration NO - Trondheim'\n"
# b"'Administration SE - G\\xc3\\xb6teborg'\n"
# b"'Administration SE - Malm\\xc3\\xb6'\n"
# b"'Administration SE - M\\xc3\\xb8lndal'\n"
# b"'Administration SE - \\xc3\\x96rebro'\n"
# b"'Administration SE - \\xc3\\x96stersund'\n"
# b"'Administration SE - Stockholm'\n"
# b"'Administration SE Eskilstuna'\n"
# b"'Administration SE Link\\xc3\\xb6ping'\n"
# b"'Administration Telefonbeskeder'\n"
# b"'Adrian Kwiatkowski'\n"
# b"'Adrian Soczynski'\n"
# b"'Adrian Stolarczyk'\n"
# b"'Adrian Ugleholdt Chifor'\n"
# b"'Adrian Wronski'\n"
# b"'Advanced Analytics'\n"
# b"'AdvoPro'\n"
# b"'AEP - Architect Excellence Program'\n"
# b"'AEP - Module 4 - Group work'\n"
# b"'Aff\\xc3\\xa4rsskolan'\n"
# b"'Aftale egen IP'\n"
# b"'Aftalegrundlag'\n"
# b"'Agder Energi RFP 2018'\n"
# b"'Agil Produktudviklingsmetode i EG KI'\n"
# b"'Agneta Frennhed'\n"
# b"'Agon Abazi'\n"
# b"'AHOE_TEST'\n"
# b"'AI/IoT/Machine Learning'\n"
# b"'Air Greenland'\n"
# b"'Aisar Alshawabkeh'\n"
# b"'Aktivitetskalender'\n"
# b"'Akutten'\n"
# b"'Aldin Beganovic'\n"
# b"'Alexander Douglas Ellice'\n"
# b"'Alexander Kirkaune'\n"
# b"'Alexander Rock'\n"
# b"'Alexander T\\xc3\\xb8mmerholen'\n"
# b"'Alf I. Larsen - FORPROSJEKT'\n"
# b"'Alf I. Larsen - Leveranse'\n"
# b"'Alfa Laval External'\n"
# b"'Ali Dezkam'\n"
# b"'Ali Dezkam (ADM)'\n"
# b"'All In Cloud'\n"
# b"'All managers in EG'\n"
# b"'All managers in EG, Denmark'\n"
# b"'All managers in EG, Norway'\n"
# b"'All managers in EG, Sweden'\n"
# b"'All resources in Denmark, \\xc3\\x85rhus'\n"
# b"'All resources in Denmark, Ballerup'\n"
# b"'All resources in Denmark, Herning'\n"
# b"'All resources in Denmark, Hj\\xc3\\xb8rring'\n"
# b"'All resources in Denmark, Kolding'\n"
# b"'All resources in Denmark, Odense'\n"
# b"'All rooms in DK \\xc3\\x85lborg'\n"
# b"'All rooms in DK \\xc3\\x85rhus'\n"
# b"'All rooms in DK Ballerup'\n"
# b"'All rooms in DK Glostrup'\n"
# b"'All rooms in DK Herning'\n"
# b"'All rooms in DK Hj\\xc3\\xb8rring'\n"
# b"'All rooms in DK Holb\\xc3\\xa6k'\n"
# b"'All rooms in DK K\\xc3\\xb8benhavn'\n"
# b"'All rooms in DK Kolding'\n"
# b"'All rooms in DK Odense'\n"
# b"'All rooms in DK Thisted'\n"
# b"'All rooms in NO Bergen'\n"
# b"'All rooms in NO Gj\\xc3\\xb8vik'\n"
# b"'All rooms in NO Oslo'\n"
# b"'All rooms in NO Sandefjord'\n"
# b"'All rooms in NO Sandnes'\n"
# b"'All rooms in NO Trondheim'\n"
# b"'All rooms in PL Warsaw'\n"
# b"'All rooms in SE G\\xc3\\xb6teborg'\n"
# b"'All rooms in SE Link\\xc3\\xb6ping'\n"
# b"'All rooms in SE Malm\\xc3\\xb6'\n"
# b"'All rooms in SE M\\xc3\\xb6lndal'\n"
# b"'All rooms in SE \\xc3\\x96rebro'\n"
# b"'All rooms in SE \\xc3\\x96stersund'\n"
# b"'All rooms in SE Stockholm'\n"
# b"'All video konferences in EG'\n"
# b"'Allan Bech'\n"
# b"'Allan Bjerrum'\n"
# b"'Allan Buhl M\\xc3\\xb8ller'\n"
# b"'Allan Iversen'\n"
# b"'Allan Jepsen'\n"
# b"'Alle Aspect4 kunder'\n"
# b"'Alle i EGU NO'\n"
# b"'Alle i \\xc3\\x96rebro (EG Computer Service AB)'\n"
# b"'Aller Medie'\n"
# b"'Alternative scenario'\n"
# b"'Altinget'\n"
# b"'Alvar Myrdal Paulsrud'\n"
# b"'AMBU'\n"
# b"'AMG-Gruppe'\n"
# b"'Amgros'\n"
# b"'AMS AX'\n"
# b"'AMS NAV'\n"
# b"'AMS Teamlead'\n"
# b"'AMS til ecom'\n"
# b"'AMS Transition'\n"
# b"'AMS-ODM'\n"
# b"'Amsterdam - World Retail Forum'\n"
# b"'AMU EG Norge'\n"
# b"'Analytics'\n"
# b"'Anastasia Shiyan'\n"
# b"'Anders Aarup'\n"
# b"'Anders Andersson'\n"
# b"'Anders Baklund'\n"
# b"'Anders Barslund'\n"
# b"'Anders Borggaard Jensen'\n"
# b"'Anders Christensen'\n"
# b"'Anders Hoffgaard'\n"
# b"'Anders Iglemose Larsen'\n"
# b"'Anders Kj\\xc3\\xa6rulff Christensen'\n"
# b"'Anders Kramer Knudsen'\n"
# b"'Anders Lindbeck'\n"
# b"'Anders Lykkegaard'\n"
# b"'Anders M\\xc3\\xb8rk'\n"
# b"'Anders Nielsen'\n"
# b"'Anders Nielsen'\n"
# b"'Anders Sandgren'\n"
# b"'Anders S\\xc3\\xb8rensen'\n"
# b"'Anders Strandgaard Borgbjerg'\n"
# b"'Anders Sunnanbris'\n"
# b"'Anders Thor\\xc3\\xa9n'\n"
# b"'Anders Trege'\n"
# b"'Anders Tuff'\n"
# b"'Andr\\xc3\\xa9 J\\xc3\\xb6nsson'\n"
# b"'Andrea Tajana'\n"
# b"'Andreas Andersson'\n"
# b"'Andreas Falkenberg'\n"
# b"'Andreas Gaarder'\n"
# b"'Andreas Hove-J\\xc3\\xb8rgensen'\n"
# b"'Andreas Jacobsen'\n"
# b"'Andreas Joensen'\n"
# b"'Andreas Kjeldskov Nielsen'\n"
# b"'Andreas Klapp'\n"
# b"'Andreas Lindefors'\n"
# b"'Andreas Nou'\n"
# b"'Ane Louise Gjelstrup'\n"
# b"'Anette Bro'\n"
# b"'Anette Lilleberg'\n"
# b"'Anette Rosengren'\n"
# b"'Anette Skaarup Hembo'\n"
# b"'Anette S\\xc3\\xb8nderskov'\n"
# b"'Anette Ungstrup Petersen'\n"
# b"'Angelika Kwiatkowska'\n"
# b"'Angular Team'\n"
# b"'AngularJS'\n"
# b"'AngularJS 2'\n"
# b"'Anita av Vollanum \\xc2\\xa0Farodane'\n"
# b"'Anita Brix Andersen'\n"
# b"'Anita Erichsen'\n"
# b"'Anita Marie Kreiling'\n"
# b"'Anita Mols Ingvartsen'\n"
# b"'Anja Bagge Persson'\n"
# b"'Anja Larsen'\n"
# b"'Ann Fleischer Vosegaard'\n"
# b"'Ann Redner'\n"
# b"'Anna Claesson'\n"
# b"'Anna Feuk'\n"
# b"'Anna Forss\\xc3\\xa9n'\n"
# b"'Anna Lene Andersen Bredvig'\n"
# b"'Anna Madsen'\n"
# b"'Anna Sj\\xc3\\xb6gestam'\n"
# b"'Anna Sj\\xc3\\xb6\\xc3\\xb6'\n"
# b"'Anna Stjernqvist'\n"
# b"'Anna-Marie Horneman'\n"
# b"'Anne Christine Bjerre B\\xc3\\xa6kke'\n"
# b"'Anne Gissel\\xc3\\xb8, Superbest'\n"
# b"'Anne Kathrine Birk Svendsen'\n"
# b"'Anne Kristine Als Helstam'\n"
# b"'Anne Lund Bertelsen'\n"
# b"'Anne Marie \\xc3\\x98stergaard'\n"
# b"'Anne Mette Ross Petersen'\n"
# b"'Anne Solev\\xc3\\xa5g'\n"
# b"'Anne Steensen Kryger'\n"
# b"'Anne-Dorthe Guldgren Petersen'\n"
# b"'Anne-Louise Waaben'\n"
# b"'Anne-Mette Andersen'\n"
# b"'Annemette M\\xc3\\xb8ller Christensen'\n"
# b"'Anne-Mette \\xc3\\x98hlers Jensen'\n"
# b"'Annethe Ingeborg Winther'\n"
# b"'Annette Berg'\n"
# b"'Annette Juhl S\\xc3\\xb8rensen'\n"
# b"'Annette Ravn'\n"
# b"'Annette Skov B\\xc3\\xb8je'\n"
# b"'Annette Troelsgaard Vaudry'\n"
# b"'Anni K\\xc3\\xa4te Stenersen Schlebaum'\n"
# b"'Annika Gustavsson'\n"
# b"'Ann-Lie Bak-Mikkelsen'\n"
# b"'Ann-Marie Karlsson'\n"
# b"'Annual_Cycle_EGCH'\n"
# b"'Anritsu - D365O'\n"
# b"'Anritsu D365O implementation'\n"
# b"'Anritsu test'\n"
# b"'Anton Adolfsson'\n"
# b"'Anurag Soni'\n"
# b"'Anv\\xc3\\xa4ndarTr\\xc3\\xa4ff'\n"
# b"'APL SDM'\n"
# b"'Apotek 1 - AMS'\n"
# b"'Apotek 1 - Avrop 18-4'\n"
# b"'Apotek 1 - avropsarbeid'\n"
# b"'Apotek 1 - avropsarbeide'\n"
# b"'Apotek 1 - Kjerneteam'\n"
# b"'Apotek1'\n"
# b"'Apotek1 - Avrop 1 2018 - Ordrel\\xc3\\xb8p'\n"
# b"'Apotek1 - Prosjekt'\n"
# b"'Apoteket AB - POS May 2018'\n"
# b"'Apoteket CRM'\n"
# b"'Apoteket D365O'\n"
# b"'Application Management Xellent'\n"
# b"'Applikations Support'\n"
# b"'Aravind.s@sonata-software.com'\n"
# b"'Arbejdsmilj\\xc3\\xb8 \\xe2\\x80\\x93 Odense Middelfartvej'\n"
# b"'Arbejdsmilj\\xc3\\xb8organisation'\n"
# b"'Arbejdsmilj\\xc3\\xb8organisation Aarhus'\n"
# b"'Arbetsmilj\\xc3\\xb6utbildning'\n"
# b"'Architect Excellence Program - Team 1'\n"
# b"'Architect Excellence Program - Team 2'\n"
# b"'Architect Excellence Programme - Managers'\n"
# b"'Arctic Group'\n"
# b"'Are Skurdal'\n"
# b"'Arild Bernth Jakobsen'\n"
# b"'Arild Enger'\n"
# b"'Arkadiusz Fajdek'\n"
# b"'Arkitekter og Presales'\n"
# b"'Arkitektur'\n"
# b"'Arkitektur'\n"
# b"'Arkitekturforum'\n"
# b"'Arkiv'\n"
# b"'Arkiv NexStep'\n"
# b"'Arne Birk Johansen'\n"
# b"'Arnfinn Berg'\n"
# b"'Arnstein Voll'\n"
# b"'AROCK'\n"
# b"'Arpine Sukiasyan'\n"
# b"'Artesa'\n"
# b"'Artur Baczak'\n"
# b"'Arvid Bornstein'\n"
# b"'ArvidEG'\n"
# b"'AS3'\n"
# b"'AS3'\n"
# b"'as4monitor'\n"
# b"'\\xc3\\x85sa Englund'\n"
# b"'Asbj\\xc3\\xb8rn Aarbakke'\n"
# b"'\\xc3\\x85se Hol'\n"
# b"'Asger Jensen'\n"
# b"'Asle Emil Ullenes'\n"
# b"'Asle Skogstad'\n"
# b"'Asmund Hoel'\n"
# b"'Asmundur Helgi Steindorsson'\n"
# b"'ASPECT4 Common Group'\n"
# b"'ASPECT4 Developers'\n"
# b"'ASPECT4 DSV'\n"
# b"'ASPECT4 Fashion'\n"
# b"'ASPECT4 Finance'\n"
# b"'Aspect4 kunder'\n"
# b"'ASPECT4 Logistics'\n"
# b"'Aspect4 NO Support'\n"
# b"'Aspect4 Online'\n"
# b"'ASPECT4 opdatering'\n"
# b"'ASPECT4 Technology Awards 2018'\n"
# b"'ASPECT4 TMS'\n"
# b"'ASPECT4 Tr\\xc3\\xa6last Developers'\n"
# b"'ASPECT4 Tr\\xc3\\xa6last og ASPECT4 Faghandel'\n"
# b"'ASPECT4 Transport'\n"
# b"'ASPECT4 Transport Misc'\n"
# b"'ASPECT4 Transport opgavestyring'\n"
# b"'ASPECT4: Building a Bright Future'\n"
# b"'ASPECT4Retail'\n"
# b"'Assad El-Nahhas'\n"
# b"'Astrid Einvik'\n"
# b"'Astrid Marie Dahl'\n"
# b"'ASVAGT'\n"
# b"'Athlon'\n"
# b"'Atle W. Haagensen'\n"
# b"'ATP'\n"
# b"'Att g\\xc3\\xb6ra'\n"
# b"'Audit 2.0'\n"
# b"'August Adelgaard'\n"
# b"'AURA'\n"
# b"'AURA inspirationsm\\xc3\\xb8de'\n"
# b"'Aura Power BI Kursus'\n"
# b"'AX - pre-utfylte ODM dokumenter'\n"
# b"'AX & D365O Consultancy and Product Management'\n"
# b"'AX & D365O Process industry Vertical'\n"
# b"'AX & D365O Production and Construction Vertical'\n"
# b"'AX & D365O Project Management'\n"
# b"'AX & D365O Service Management'\n"
# b"'AX & D365O Service Vertical'\n"
# b"'AX & D365O Serviceline'\n"
# b"'AX & Dynamics365 Retail and Distribution'\n"
# b"'AX 2012'\n"
# b"'AX 7 - Certifications'\n"
# b"'AX and D365FO Development'\n"
# b"'AX Ballerup'\n"
# b"'AX Consulting Oslo-Bergen (876)'\n"
# b"'AX Consulting Stavanger-Trondheim (878)'\n"
# b"'AX Development Capability'\n"
# b"'AX Finance'\n"
# b"'AX Finance SE'\n"
# b"'AX Graduate 2016/2017'\n"
# b"'AX Handheld device'\n"
# b"'AX HR feature'\n"
# b"'AX Installation'\n"
# b"'AX Kolding'\n"
# b"'AX Norge'\n"
# b"'AX Norge'\n"
# b"'AX Serviceline, Management Group'\n"
# b"'AX Support Sweden'\n"
# b"'AX Utility Sales Sweden'\n"
# b"'AX_BAL'\n"
# b"'Axel \\xc3\\x96rn Kristj\\xc3\\xa1nsson'\n"
# b"'Axel Sundstr\\xc3\\xb6m'\n"
# b"'AXPoland'\n"
# b"'Azhar Iqbal'\n"
# b"'Azure Stack'\n"
# b"'BA ugeplan'\n"
# b"'Babak Yousefi'\n"
# b"'BabySam'\n"
# b"'BabySam NAV2017 LS Retail'\n"
# b"'Babysam transition Hosting O365'\n"
# b"'Bakels Aromatic'\n"
# b"'Bakels F\\xc3\\xb6rstudie uppgradering'\n"
# b"'Balaji Nunna'\n"
# b"'Ballerup Projektor 1'\n"
# b"'Ballerup Projektor 2'\n"
# b"'Ballerup Projektor 3'\n"
# b"'Ballerup Restricted Managed Services'\n"
# b"'Ballerup, 0 floor, Jupiter (32), ext'\n"
# b"'Ballerup, 0 floor, Mars (12), ext'\n"
# b"'Ballerup, 0 floor, Merkur (10), ext'\n"
# b"'Ballerup, 0 floor, Neptun (10), ext'\n"
# b"'Ballerup, 0 floor, Venus (5), ext'\n"
# b"'Ballerup, 1 floor, Jorden 1 (2), int'\n"
# b"'Ballerup, 1 floor, Jorden 2 (2), int'\n"
# b"'Ballerup, 1 floor, Jorden 3 (6), int'\n"
# b"'Ballerup, 1 floor, Jorden 4 (10), int'\n"
# b"'Ballerup, 1 floor, Jorden 5 (8), int'\n"
# b"'Ballerup, 1 floor, Jorden 6 (6), int'\n"
# b"'Ballerup, 1 floor, Karlsvognen (8), ext'\n"
# b"'Ballerup, 1 floor, Orion (4), ext'\n"
# b"'Ballerup, 2 floor, Lillebj\\xc3\\xb8rn (4), ext'\n"
# b"'Ballerup, 2 floor, M\\xc3\\xa5nen 1 (2), int'\n"
# b"'Ballerup, 2 floor, M\\xc3\\xa5nen 2 (7), int'\n"
# b"'Ballerup, 2 floor, M\\xc3\\xa5nen 3 (6), int'\n"
# b"'Ballerup, 2 floor, M\\xc3\\xa5nen 4 (2), int'\n"
# b"'Ballerup, 2 floor, M\\xc3\\xa5nen 5 (8), int'\n"
# b"'Ballerup, 2 floor, M\\xc3\\xa5nen 6 (10), int'\n"
# b"'Ballerup, 2 floor, M\\xc3\\xa5nen 8 (6), int'\n"
# b"'Ballerup, 2 floor, Storebj\\xc3\\xb8rn (8), ext'\n"
# b"'Ballerup, 3 floor, Cassiopeia (4), ext'\n"
# b"'Ballerup, 3 floor, M\\xc3\\xa6lkevejen (8), ext'\n"
# b"'Ballerup, 3 floor, Pluto 1 (2), int'\n"
# b"'Ballerup, 3 floor, Pluto 2 (4), int'\n"
# b"'Ballerup, 3 floor, Pluto 3 (6), int'\n"
# b"'Ballerup, 3 floor, Pluto 4 (2), int'\n"
# b"'Ballerup, 3 floor, Pluto 6 (20), int'\n"
# b"'Ballerup, 3 floor, Pluto 8 (6), int'\n"
# b"'Ballerup, 4 floor, Nordstjernen (4), ext'\n"
# b"'Ballerup, 4 floor, Sirius (8), ext'\n"
# b"'Ballerup, 4 floor, Solen 1 (2), int'\n"
# b"'Ballerup, 4 floor, Solen 2 (4), int'\n"
# b"'Ballerup, 4 floor, Solen 3 (6), int'\n"
# b"'Ballerup, 4 floor, Solen 4 (12), int'\n"
# b"'Ballerup, 4 floor, Solen 6 (6), int'\n"
# b"'Ballerup, Kursuslokale 1 (12), (bookes via kursus@eg.dk)'\n"
# b"'Bank Data D365 Udbud'\n"
# b"'Bank integration'\n"
# b"'B\\xc3\\xa5rd S\\xc3\\xa6ther'\n"
# b"'Bar\\xc5\\x82omiej \\xc5\\xbbuk'\n"
# b"'Bartosz Stelmaszuk'\n"
# b"'BAS Managed Services Management'\n"
# b"'BAS Maskinutleie CRM implementering'\n"
# b"'BAS Maskinutleie CRM prosjekt'\n"
# b"'Base & Finance'\n"
# b"'BA-Tavle - Ugens opgaver'\n"
# b"'BAYOU'\n"
# b"'BCHG Finance'\n"
# b"'BCHG Projects'\n"
# b"'BCHG webplatforme'\n"
# b"'BCHG workshop - Office 365, Collaboration & CRM'\n"
# b"'BDO'\n"
# b"'BDO - MDM and Azure'\n"
# b"'BDO MDM'\n"
# b"'BDO Team'\n"
# b"'Beer Sten'\n"
# b"'Beijer temporary folder'\n"
# b"'Bengt Eriksen'\n"
# b"'Bengt Persson'\n"
# b"'Bengt-Greger Os'\n"
# b"'Benn Jochumsen, SuperBest'\n"
# b"'Benni Hansen'\n"
# b"'Benny Jepsen'\n"
# b"'Bent A. Ulevik'\n"
# b"'Bent Dalsgaard'\n"
# b"'Bent H\\xc3\\xb8st'\n"
# b"'Bent Pagh'\n"
# b"'Bente Brasch'\n"
# b"'Bente Kirstine S\\xc3\\xb8gaard'\n"
# b"'Bente Nielsen'\n"
# b"'Bente Reng-Andersen'\n"
# b"'Bente Vestergaard'\n"
# b"'Beregnerservice'\n"
# b"'Beregnerservice'\n"
# b"'Berge Sag - POS l\\xc3\\xb8sning'\n"
# b"'Bergen, M\\xc3\\xb8terum Bl\\xc3\\xa5tann (10)'\n"
# b"'Berit Frydendal'\n"
# b"'Berit Holst'\n"
# b"'Berit Jessen (SuperGros)'\n"
# b"'Berit Schaldemose'\n"
# b"'Berit Thomsen'\n"
# b"'Berno Norton'\n"
# b"'Betaplan'\n"
# b"'Betina Kammer Bertz'\n"
# b"'Betina Young Andersen'\n"
# b"'Bettina Rysbjerg H\\xc3\\xb8jfeldt'\n"
# b"'BF'\n"
# b"'BI for Dynamics UTB'\n"
# b"'BI Icons'\n"
# b"'BI Oslo'\n"
# b"'Bibi Nyborg Madsen'\n"
# b"'Bid - Stockholm Gas'\n"
# b"'Bid Approval Committee (BAC)'\n"
# b"'Bid Management office'\n"
# b"'Bid Management Public'\n"
# b"'Bid samarbejde'\n"
# b"'BigData'\n"
# b"'BI-konferenser 2018'\n"
# b"'Bilag 8a arbejds site'\n"
# b"'Bilal Ince'\n"
# b"'Biltema'\n"
# b"'Birger Alnes'\n"
# b"'Birger Larsen'\n"
# b"'Birgit Egesb\\xc3\\xa6k'\n"
# b"'Birgit Elisabeth M\\xc3\\xb8ller Jensen'\n"
# b"'Birgit Juhl Vestergaard'\n"
# b"'Birgit Reiner-Holm'\n"
# b"'Birgit Snustad Viken'\n"
# b"'Birgitta Eklund'\n"
# b"'Birgitta Hultgren'\n"
# b"'Birgitte Boesen Qvist'\n"
# b"'Birgitte Brenden'\n"
# b"'Birgitte Krogsdorf-Jensen'\n"
# b"'Birgitte Lindahl Rasmussen'\n"
# b"'Birgitte L\\xc3\\xb8gsted N\\xc3\\xb8rgaard'\n"
# b"'Birgitte M\\xc3\\xb8ller Hansen'\n"
# b"'Birte R\\xc3\\xb8rstad'\n"
# b"'Birthe Baes'\n"
# b"'BITS'\n"
# b"'Bjarne Aarup'\n"
# b"'Bjarne Andersen'\n"
# b"'Bjarne Bentsen'\n"
# b"'Bjarne Boesen'\n"
# b"'Bjarne Frederiksen'\n"
# b"'Bjarne Ingerslev'\n"
# b"'Bjarne Kvamme'\n"
# b"'Bjarne S\\xc3\\xb8rensen'\n"
# b"'Bjarne Vering Johansen'\n"
# b"'Bjarni Nielsen'\n"
# b"'Bjarte Moberg'\n"
# b"'Bj\\xc3\\xb8rg Maren \\xc3\\x98fsti'\n"
# b"'Bj\\xc3\\xb8rn Henrik Moshuus'\n"
# b"'Bj\\xc3\\xb6rn Malm'\n"
# b"'Bj\\xc3\\xb8rn Nicolaysen'\n"
# b"'Bj\\xc3\\xb8rn Olesen'\n"
# b"'Bj\\xc3\\xb8rn Ove Halvorsen'\n"
# b"'Bj\\xc3\\xb8rn Petter Vennesland Kysnes'\n"
# b"'Bj\\xc3\\xb8rn Strandberg'\n"
# b"'Bj\\xc3\\xb6rn Tikkanen'\n"
# b"'Blodomloppet 2018 - EG \\xc3\\x96rebro'\n"
# b"'Blue Ridge Demand Forecast/Planner hos Gausdal'\n"
# b"'BMK Drive Tr\\xc3\\xa4nare'\n"
# b"'Bo Eriksen'\n"
# b"'Bo Flemming Bay'\n"
# b"'Bo Hjorth Christiansen'\n"
# b"'Bo Lyngholm Andersen'\n"
# b"'Bo Olesen'\n"
# b"'Bo Sanick'\n"
# b"'Bo Wilhelmsen'\n"
# b"'Bob Byggemand'\n"
# b"'Bodil Hesselbjerg Larsen'\n"
# b"'Bodil Jensen'\n"
# b"'Bodil Uls\\xc3\\xb8e-Hansen'\n"
# b"'BODUL personal'\n"
# b"'Bodum'\n"
# b"'B\\xc3\\xb8je Lind Utoft'\n"
# b"'Boligmails 2016'\n"
# b"'BOLLA plan test'\n"
# b"'bolla_pt_prioriteringer'\n"
# b"'Boots Apotek Norge'\n"
# b"'Bostik'\n"
# b"'bowling'\n"
# b"'Brandsoft Konvertering'\n"
# b"'Brandsoft Sluse'\n"
# b"'Brandsoft Support'\n"
# b"'Brandsoft Teknik'\n"
# b"'Brenderup - Fawkes'\n"
# b"'Brian Braad Nielsen'\n"
# b"'Brian Brok-J\\xc3\\xb8rgensen'\n"
# b"'Brian G. Frandsen'\n"
# b"'Brian Jensen'\n"
# b"'Brian Kj\\xc3\\xa6r'\n"
# b"'Brian Larsen'\n"
# b"'Brian Nebelong'\n"
# b"'Brian Olaf Korntved'\n"
# b"'Brian Poulsgaard'\n"
# b"'Brian Rasmussen'\n"
# b"'Brian Siim Andersen'\n"
# b"'Brian Sk\\xc3\\xa5rup'\n"
# b"'Brian S\\xc3\\xb8rensen'\n"
# b"'Brian Sparwath'\n"
# b"'Brian Wested Laursen'\n"
# b"'Bring SCM'\n"
# b"'Bring SCM/Ikea Food Supply'\n"
# b"'Brita Lid L\\xc3\\xb8land'\n"
# b"'Britt Maiken Hansson'\n"
# b"'Britt Reenberg'\n"
# b"'Britta Kejlberg Gundlund'\n"
# b"'Britta Toft B\\xc3\\xb8hme'\n"
# b"'Britt-Marie Bengtsson'\n"
# b"'BroBizz'\n"
# b"'Broen Lab'\n"
# b"'Br\\xc3\\xb6llops planering'\n"
# b"'Br\\xc3\\xb8ndby Kommune Udbud af \\xc3\\xb8konomi- og L\\xc3\\xb8nsystemer'\n"
# b"'Brown bag sessions'\n"
# b"'BRS - BYG'\n"
# b"'BRS - BYG - system arkiv'\n"
# b"'BRS - Servicedesk - BYG'\n"
# b"'BRS Byg - NBL BYG'\n"
# b"'BRS BYG Kalkulation'\n"
# b"'BRS Byg Salg'\n"
# b"'BRS EG Bolig Support'\n"
# b"'BRS Facebook'\n"
# b"'BRS Growth Model'\n"
# b"'BRS Healthcare'\n"
# b"'BRS HealthCare - Migrering fra MedWin til Clinea'\n"
# b"'BRS Healthcare - Migrering til EG Clinea'\n"
# b"'BRS Healthcare - New customers status group'\n"
# b"'BRS Healthcare - Product management'\n"
# b"'BRS Healthcare - R\\xc3\\x98S Sygehus Lilleb\\xc3\\xa6lt'\n"
# b"'BRS Healthcare Management'\n"
# b"'BRS Healthcare Migrering'\n"
# b"'BRS Healthcare Project'\n"
# b"'BRS Healthcare Projekt Brandsoft Finans'\n"
# b"'BRS Healthcare Projektafdeling'\n"
# b"'BRS Healthcare Teknik'\n"
# b"'BRS Healthcare Udvikling'\n"
# b"'BRS Management'\n"
# b"'BRS Management actions'\n"
# b"'BRS Proces og metode'\n"
# b"'BRS Sales'\n"
# b"'BRS SALG INNOVATION'\n"
# b"'BRS Web'\n"
# b"'BRS-Hackerthon'\n"
# b"'BRS-Healthcare El og teleafd.'\n"
# b"'Br\\xc3\\xbcel - D365 for Operations'\n"
# b"'Bruno Buhl'\n"
# b"'BS'\n"
# b"'BS Oppgaver etter m\\xc3\\xb8te 11.10.2017'\n"
# b"'BU 110_EG Bolig _ Kontrakter'\n"
# b"'BU 110_EG STRATO _ Kontrakter'\n"
# b"'BU 347_EG Legal _ Kontrakter'\n"
# b"'BU 555'\n"
# b"'BU 580 NexStep'\n"
# b"'BU Strategies'\n"
# b"'bu213'\n"
# b"'Buddy Aarhus'\n"
# b"'BUS_001_EGDK_Koncernen'\n"
# b"'BUS_001_EGNC_Koncernen'\n"
# b"'BUS_001_EGSD_Koncernen'\n"
# b"'BUS_001_EGSU_Koncernen'\n"
# b"'BUS_001_EGTO_Koncernen'\n"
# b"'BUS_001_PUBL_Koncernen'\n"
# b"'BUS_002_EGDK_Corporate Marketing'\n"
# b"'BUS_002_EGNC_Corporate Marketing'\n"
# b"'BUS_002_EGSU_Corporate Marketing'\n"
# b"'BUS_002_EGTO_Corporate Marketing'\n"
# b"'BUS_004_EGDK_EG Holding'\n"
# b"'BUS_006_EGDK_Buffer'\n"
# b"'BUS_007_EGDK_Corporate IT'\n"
# b"'BUS_007_EGNC_Corporate IT'\n"
# b"'BUS_007_EGSU_Corporate IT'\n"
# b"'BUS_008_EGDK_Business Development'\n"
# b"'BUS_010_EGDK_EG IT'\n"
# b"'BUS_015_DYNA_Procurement'\n"
# b"'BUS_015_EGDK_Procurement'\n"
# b"'BUS_015_EGEM_Procurement'\n"
# b"'BUS_015_EGNC_Procurement'\n"
# b"'BUS_015_EGSD_Procurement'\n"
# b"'BUS_015_EGSU_Procurement'\n"
# b"'BUS_015_EGTO_Procurement'\n"
# b"'BUS_015_PUBL_Procurement'\n"
# b"'BUS_018_EGDK_EGDC'\n"
# b"'BUS_061_EGDK_Facility'\n"
# b"'BUS_061_EGEM_Facility'\n"
# b"'BUS_061_EGNC_Facility'\n"
# b"'BUS_061_EGSD_Facility'\n"
# b"'BUS_061_EGSU_Facility'\n"
# b"'BUS_061_EGTO_Facility'\n"
# b"'BUS_061_PUBL_Facility'\n"
# b"'BUS_067_EGDK_Administration, Service'\n"
# b"'BUS_067_EGNC_Administration, Service'\n"
# b"'BUS_067_EGSU_Administration, Service'\n"
# b"'BUS_067_EGTO_Administration, Service'\n"
# b"'BUS_070_EGDK_Business Finance Development'\n"
# b"'BUS_071_EGDK_Finance'\n"
# b"'BUS_071_EGGL_Finance'\n"
# b"'BUS_071_EGNC_Finance'\n"
# b"'BUS_071_EGSU_Finance'\n"
# b"'BUS_071_EGTO_Finance'\n"
# b"'BUS_072_DYNA_Controlling'\n"
# b"'BUS_072_EGDK_Group Controlling'\n"
# b"'BUS_072_EGEM_Controlling'\n"
# b"'BUS_072_EGGL_Controlling'\n"
# b"'BUS_072_EGNC_Group Controlling'\n"
# b"'BUS_072_EGSE_Group Controlling'\n"
# b"'BUS_072_EGSU_Group Controlling'\n"
# b"'BUS_072_EGTO_Controlling'\n"
# b"'BUS_072_PUBL_Controlling'\n"
# b"'BUS_075_EGDK_Analytics'\n"
# b"'BUS_077_EGDK_Financial Planning and Analysis'\n"
# b"'BUS_078_EGDK_GDPR'\n"
# b"'BUS_078_EGNC_GDPR'\n"
# b"'BUS_079_EGDK_Business Partnering'\n"
# b"'BUS_079_EGSU_Business Partnering'\n"
# b"'BUS_081_EGDK_Human Resource'\n"
# b"'BUS_081_EGNC_Human Resource'\n"
# b"'BUS_081_EGSU_Human Resource'\n"
# b"'BUS_087_EGDK_FGROUP'\n"
# b"'BUS_087_EGNC_FGROUP'\n"
# b"'BUS_087_EGSU_FGROUP'\n"
# b"'BUS_092_EGDK_Leasing IFRS 16'\n"
# b"'BUS_093_DYNA_Overhead'\n"
# b"'BUS_093_EGDK_Overhead'\n"
# b"'BUS_093_EGNC_Overhead'\n"
# b"'BUS_093_EGSD_Overhead'\n"
# b"'BUS_093_EGSU_Overhead'\n"
# b"'BUS_093_EGTO_Overhead'\n"
# b"'BUS_093_PUBL_Overhead'\n"
# b"'BUS_095_EGDK_Corp PMO'\n"
# b"'BUS_097_EGDK_Management Consulting & Process Management Office'\n"
# b"'BUS_101_EGDK_Global Delivery'\n"
# b"'BUS_101_EGNC_Operations Management'\n"
# b"'BUS_105_EGDK_CTO Management'\n"
# b"'BUS_110_EGDK_EG Bolig'\n"
# b"'BUS_121_EGDK_Human Resource'\n"
# b"'BUS_121_EGNC_Human Resource'\n"
# b"'BUS_121_EGSU_Human Resource'\n"
# b"'BUS_121_EXDK_Human Resource'\n"
# b"'BUS_121_EXNO_Human Resource'\n"
# b"'BUS_121_EXSE_Human Resource'\n"
# b"'BUS_122_EGDK_PMO'\n"
# b"'BUS_122_EXDK_PMO'\n"
# b"'BUS_123_EXDK_IT Operations'\n"
# b"'BUS_124_EXDK_Overhead'\n"
# b"'BUS_124_EXNO_Overhead'\n"
# b"'BUS_124_EXSE_Overhead'\n"
# b"'BUS_125_EGDK_Service overhead'\n"
# b"'BUS_125_EGNC_Service overhead'\n"
# b"'BUS_125_EGSU_Service overhead'\n"
# b"'BUS_133_EGDK_Service design & Technology Innovation'\n"
# b"'BUS_133_EXDK_Service design & Technology Innovation'\n"
# b"'BUS_135_EGDK_Corporate Marketing'\n"
# b"'BUS_135_EGNC_Corporate Marketin'\n"
# b"'BUS_135_EXDK_Corporate Marketing'\n"
# b"'BUS_135_EXNO_Corporate Marketin'\n"
# b"'BUS_137_EGDK_Business Partnering'\n"
# b"'BUS_137_EGSU_Business Partnering'\n"
# b"'BUS_137_EXDK_Business Partnering'\n"
# b"'BUS_138_EGDK_Finance'\n"
# b"'BUS_138_EXDK_Finance'\n"
# b"'BUS_138_EXNO_Finance'\n"
# b"'BUS_138_EXSE_Finance'\n"
# b"'BUS_139_EGDK_Group Controlling'\n"
# b"'BUS_139_EXDK_Group Controlling'\n"
# b"'BUS_150_EGDK_Brandsoft'\n"
# b"'BUS_213_EGDK_ASPECT4'\n"
# b"'BUS_213_EGNC_ASPECT4'\n"
# b"'BUS_240_EGDK_Infrastructure Cloud Services'\n"
# b"'BUS_280_EGDK_Xellent'\n"
# b"'BUS_280_EGNC_Xellent'\n"
# b"'BUS_280_EGSU_Xellent'\n"
# b"'BUS_282_EGDK_Utility Solutions'\n"
# b"'BUS_282_EGNC_Utility Solutions'\n"
# b"'BUS_282_EGSU_Zynergy'\n"
# b"'BUS_283_EGDK_Utility Nordic Sales & Management'\n"
# b"'BUS_283_EGSU_Utility Nordic Sales & Management'\n"
# b"'BUS_321_EGDK_Sales Utility'\n"
# b"'BUS_321_EGSU_Sales Utility'\n"
# b"'BUS_337_EGDK_PMO'\n"
# b"'BUS_347_EGDK_EG Legal'\n"
# b"'BUS_387_EGDK_FSW'\n"
# b"'BUS_387_EGNC_FSW'\n"
# b"'BUS_387_EGSU_FSW'\n"
# b"'BUS_401_EGDK_VBS Service Delivery Management'\n"
# b"'BUS_401_EGNC_VBS Service Delivery Management'\n"
# b"'BUS_401_EGSU_VBS Service Delivery Management'\n"
# b"'BUS_401_EXDK_VBS Service Delivery Management'\n"
# b"'BUS_401_EXNO_VBS Service Delivery Management'\n"
# b"'BUS_401_EXSE_VBS Service Delivery Management'\n"
# b"'BUS_405_EGDK_Delivery Excellence'\n"
# b"'BUS_405_EGNC_Delivery Excellence'\n"
# b"'BUS_405_EGSU_Sales & Delivery Support'\n"
# b"'BUS_405_EXDK_Delivery Excellence'\n"
# b"'BUS_405_EXNO_Delivery Excellence'\n"
# b"'BUS_407_EGDK_Account Management'\n"
# b"'BUS_408_EGDK_Sales Retail, Media & Fashion'\n"
# b"'BUS_408_EGNC_Sales Retail, Media & Fashion'\n"
# b"'BUS_408_EGSU_Sales Retail, Media & Fashion'\n"
# b"'BUS_408_EXDK_Sales Retail, Media & Fashion'\n"
# b"'BUS_408_EXNO_Sales Retail, Media & Fashion'\n"
# b"'BUS_408_EXSE_Sales Retail, Media & Fashion'\n"
# b"'BUS_409_EGDK_Digital Transformation Services'\n"
# b"'BUS_409_EGNC_Digital Transformation Services'\n"
# b"'BUS_409_EGSU_Digital Transformation Services'\n"
# b"'BUS_409_EXDK_Digital Transformation Services'\n"
# b"'BUS_409_EXNO_Digital Transformation Services'\n"
# b"'BUS_409_EXSE_Digital Transformation Services'\n"
# b"'BUS_410_EGDK_EG Byg & Installation'\n"
# b"'BUS_411_EGDK_Business Ready Solutions Sales'\n"
# b"'BUS_412_EGDK_Retail Solutions'\n"
# b"'BUS_412_EGSU_FACKTA Retail'\n"
# b"'BUS_413_EGSU_Retail Solutions Sales'\n"
# b"'BUS_426_EGDK_EG L\\xc3\\xb8nservice'\n"
# b"'BUS_432_EGDK_EG Logistik & Produktion NAV \\xc3\\x98st'\n"
# b"'BUS_434_EGDK_NAV'\n"
# b"'BUS_434_EGNC_NAV'\n"
# b"'BUS_434_EGSU_NAV'\n"
# b"'BUS_440_EGDK_AX Product Development'\n"
# b"'BUS_442_DYNA_Dynaway'\n"
# b"'BUS_450_EGDK_Business Ready Solutions Management'\n"
# b"'BUS_453_EGDK_PMO Projects'\n"
# b"'BUS_462_EGDK_Infor M3'\n"
# b"'BUS_462_EGSU_Infor M3'\n"
# b"'BUS_462_EXDK_Infor M3'\n"
# b"'BUS_462_EXSE_Infor M3'\n"
# b"'BUS_463_EGSU_M3 Sales'\n"
# b"'BUS_466_EGDK_SAP'\n"
# b"'BUS_466_EGNC_SAP'\n"
# b"'BUS_466_EXDK_SAP'\n"
# b"'BUS_466_EXNO_SAP'\n"
# b"'BUS_472_EGDK_AX'\n"
# b"'BUS_472_EGGL_AX'\n"
# b"'BUS_472_EGNC_AX'\n"
# b"'BUS_472_EGSU_AX'\n"
# b"'BUS_472_EXSE_AX'\n"
# b"'BUS_473_EGDK_AX Coe & PD'\n"
# b"'BUS_473_EGNC_AX CoE & PD'\n"
# b"'BUS_473_EGSU_AX Coe & PD'\n"
# b"'BUS_477_EGDK_Project Management'\n"
# b"'BUS_477_EGNC_Project Management'\n"
# b"'BUS_480_EGDK_Sales Manufacturing & Construction'\n"
# b"'BUS_480_EGNC_Sales Manufacturing & Construction'\n"
# b"'BUS_480_EGSU_Sales Manufacturing & COnstruction'\n"
# b"'BUS_480_EXDK_Sales Manufacturing & Construction'\n"
# b"'BUS_480_EXNO_Sales Manufacturing & Construction'\n"
# b"'BUS_480_EXSE_Sales Manufacturing & COnstruction'\n"
# b"'BUS_482_EGDK_EG Digital'\n"
# b"'BUS_482_EGNC_EG Digital'\n"
# b"'BUS_482_EGSU_EG Digital'\n"
# b"'BUS_486_EGDK_AX, Production & Construction'\n"
# b"'BUS_486_EGNC_AX, Production & Construction'\n"
# b"'BUS_486_EGSU_AX, production & Construction'\n"
# b"'BUS_486_EXDK_AX, Production & Construction'\n"
# b"'BUS_486_EXNO_AX, Production & Construction'\n"
# b"'BUS_486_EXSE_AX, production & Construction'\n"
# b"'BUS_490_EGDK_AX, Process Industry'\n"
# b"'BUS_490_EGNC_AX, Process Industry'\n"
# b"'BUS_490_EGSU_AX, Process Industry'\n"
# b"'BUS_490_EXDK_AX, Process Industry'\n"
# b"'BUS_490_EXNO_AX, Process Industry'\n"
# b"'BUS_490_EXSE_AX, Process Industry'\n"
# b"'BUS_492_EGDK_AX, Retail & Distribution'\n"
# b"'BUS_492_EGNC_AX, Retail & Distribution'\n"
# b"'BUS_492_EGSU_AX, Retail & Distribution'\n"
# b"'BUS_492_EXDK_AX, Retail & Distribution'\n"
# b"'BUS_492_EXNO_AX, Retail & Distribution'\n"
# b"'BUS_492_EXSE_AX, Retail & Distribution'\n"
# b"'BUS_494_EGDK_AX, Service'\n"
# b"'BUS_494_EGNC_AX, Service'\n"
# b"'BUS_494_EGSU_AX, Service'\n"
# b"'BUS_494_EXDK_AX, Service'\n"
# b"'BUS_494_EXNO_AX, Service'\n"
# b"'BUS_494_EXSE_AX, Service'\n"
# b"'BUS_497_EGDK_AX, Cross Industry'\n"
# b"'BUS_497_EGNC_AX, Cross Industry'\n"
# b"'BUS_497_EGSU_AX, Cross Industry'\n"
# b"'BUS_497_EXDK_AX, Cross Industry'\n"
# b"'BUS_497_EXNO_AX, Cross Industry'\n"
# b"'BUS_497_EXSE_AX, Cross Industry'\n"
# b"'BUS_499_EGDK_AX, Management & PD'\n"
# b"'BUS_499_EGNC_AX, Management & PD'\n"
# b"'BUS_499_EGSU_AX, Management & PD'\n"
# b"'BUS_499_EXDK_AX, Management & PD'\n"
# b"'BUS_499_EXNO_AX, Management & PD'\n"
# b"'BUS_499_EXSE_AX, Management & PD'\n"
# b"'BUS_502_EGDK_VBS Service Delivery Management'\n"
# b"'BUS_502_EXDK_VBS Service Delivery Management'\n"
# b"'BUS_505_EGDK_Strategic Projects & GD'\n"
# b"'BUS_505_EXDK_Strategic Projects & GD'\n"
# b"'BUS_508_EGDK_Managed Services Sales'\n"
# b"'BUS_508_EGNC_Managed Services Sales'\n"
# b"'BUS_508_EGSU_Managed Services Sales'\n"
# b"'BUS_508_EXDK_Managed Services Sales'\n"
# b"'BUS_508_EXNO_Managed Services Sales'\n"
# b"'BUS_508_EXSE_Managed Services Sales'\n"
# b"'BUS_510_EGDK_HW Sales'\n"
# b"'BUS_510_EXDK_HW Sales'\n"
# b"'BUS_511_EGDK_Hardware Sales SW'\n"
# b"'BUS_515_EGDK_Platform Services'\n"
# b"'BUS_515_EGNC_Platform Services'\n"
# b"'BUS_515_EGSU_Platform Services'\n"
# b"'BUS_515_EXDK_Platform Services'\n"
# b"'BUS_515_EXNO_Platform Services'\n"
# b"'BUS_515_EXSE_Platform Services'\n"
# b"'BUS_520_EGDI_Administration'\n"
# b"'BUS_530_EGDK_SDM'\n"
# b"'BUS_530_EGSU_SDM'\n"
# b"'BUS_530_EXDK_SDM'\n"
# b"'BUS_530_EXSE_SDM'\n"
# b"'BUS_545_EGNC_IT Minds'\n"
# b"'BUS_545_EGSU_IT-Minds'\n"
# b"'BUS_550_EGDK_AMS for Enterprise'\n"
# b"'BUS_555_EGDK_Digital Solutions'\n"
# b"'BUS_555_EGNC_Digital Solutions'\n"
# b"'BUS_555_EGSU_Digital Solutions'\n"
# b"'BUS_555_EXDK_Digital Solutions'\n"
# b"'BUS_555_EXNO_Digital Solutions'\n"
# b"'BUS_555_EXSE_Digital Solutions'\n"
# b"'BUS_556_EGDK_IBM Team'\n"
# b"'BUS_556_EXDK_IBM Team'\n"
# b"'BUS_560_EGDK_EG Kursus'\n"
# b"'BUS_570_EGDK_Managed Service'\n"
# b"'BUS_570_EGNC_Managed Service'\n"
# b"'BUS_570_EGSU_Managed Service'\n"
# b"'BUS_570_EXDK_Managed Service'\n"
# b"'BUS_570_EXNO_Managed Service'\n"
# b"'BUS_570_EXSE_Managed Service'\n"
# b"'BUS_571_EGDK_Managed Services SW'\n"
# b"'BUS_576_EGDK_AX, AMS Delivery'\n"
# b"'BUS_576_EGSU_AX, AMS Delivery'\n"
# b"'BUS_576_EXDK_AX, AMS Delivery'\n"
# b"'BUS_576_EXNO_AX, AMS Delivery'\n"
# b"'BUS_576_EXSE_AX, AMS Delivery'\n"
# b"'BUS_577_EGDK_AMS - NAV'\n"
# b"'BUS_577_EXDK_AMS - NAV'\n"
# b"'BUS_580_EGNC_Nexstep'\n"
# b"'BUS_595_EGDK_Service Design & Technology Innovation'\n"
# b"'BUS_596_EGDK_Software Transformation'\n"
# b"'BUS_650_EGDK_EG Healthcare'\n"
# b"'BUS_670_EGDK_EG Hairtools'\n"
# b"'BUS_670_EGHT_Hairtools'\n"
# b"'BUS_670_EGMA_Hairtools'\n"
# b"'BUS_670_EGNC_EG Hairtools'\n"
# b"'BUS_680_EGDK_Notaplan'\n"
# b"'BUS_680_EGMA_Notaplan DK'\n"
# b"'BUS_680_EGNC_Notaplan'\n"
# b"'BUS_680_EGSU_Notaplan'\n"
# b"'BUS_681_EGDK_Codezoo'\n"
# b"'BUS_681_EGMA_Codezoo'\n"
# b"'BUS_681_EGNC_Codezoo'\n"
# b"'BUS_681_EGSU_Codezoo'\n"
# b"'BUS_682_EGDK_Xena'\n"
# b"'BUS_682_EGMA_Xena DK'\n"
# b"'BUS_701_EGDK_CS Management'\n"
# b"'BUS_701_EGNC_CS Management'\n"
# b"'BUS_701_EGSD_CS Management'\n"
# b"'BUS_701_EGSU_CS Management'\n"
# b"'BUS_701_EGTO_CS Management'\n"
# b"'BUS_701_PUBL_CS Management'\n"
# b"'BUS_702_PUBL_Admin Solutions'\n"
# b"'BUS_704_EGDK_Kommune Projekter'\n"
# b"'BUS_705_EGDK_\\xc3\\x98S indsigt'\n"
# b"'BUS_710_EGDK_Delivery Excellence'\n"
# b"'BUS_720_EGTO_Social Care'\n"
# b"'BUS_727_EGEM_EG e-mergency'\n"
# b"'BUS_727_EGTO_EG e-mergency'\n"
# b"'BUS_765_EGDK_SD Management'\n"
# b"'BUS_765_EGSD_SD Management'\n"
# b"'BUS_766_EGDK_SD Ressource Management'\n"
# b"'BUS_766_EGSD_SD Ressource Management'\n"
# b"'BUS_770_EGDK_SD Payroll'\n"
# b"'BUS_770_EGSD_SD Payroll'\n"
# b"'BUS_782_EGDK_SD Delivery & Support'\n"
# b"'BUS_782_EGSD_SD Delivery & Support'\n"
# b"'BUS_833_EGDK_NAV Product Development'\n"
# b"'BUS_833_EGNC_NAV Product Development'\n"
# b"'BUS_833_EGSU_NAV Product Development'\n"
# b"'BUS_833_EXDK_NAV Product Development'\n"
# b"'BUS_833_EXNO_NAV Product Development'\n"
# b"'BUS_833_EXSE_NAV Product Development'\n"
# b"'BUS_834_EGDK_NAV Construction'\n"
# b"'BUS_834_EGNC_NAV Construction'\n"
# b"'BUS_834_EXDK_NAV Construction'\n"
# b"'BUS_834_EXNO_NAV Construction'\n"
# b"'BUS_835_EGDK_NAV Retail'\n"
# b"'BUS_835_EGNC_NAV Retail'\n"
# b"'BUS_835_EGSU_NAV Retail SE'\n"
# b"'BUS_835_EXDK_NAV Retail'\n"
# b"'BUS_835_EXNO_NAV Retail'\n"
# b"'BUS_835_EXSE_NAV Retail SE'\n"
# b"'BUS_836_EGDK_NAV Fashion'\n"
# b"'BUS_836_EGNC_NAV Fashion'\n"
# b"'BUS_836_EXDK_NAV Fashion'\n"
# b"'BUS_836_EXNO_NAV Fashion'\n"
# b"'BUS_837_EGDK_NAV Management'\n"
# b"'BUS_837_EXDK_NAV Management'\n"
# b"'BUS_838_EGDK_NAV Project Management'\n"
# b"'BUS_838_EGNC_NAV Project Management NO'\n"
# b"'BUS_838_EXDK_NAV Project Management'\n"
# b"'BUS_838_EXNO_NAV Project Management NO'\n"
# b"'BUS_844_EGDK_AX Develoment 2'\n"
# b"'BUS_850_EGNC_EG Bygg & Installation Norge'\n"
# b"'BUS_875_EGDK_COE'\n"
# b"'BUS_887_EGDK_FSE'\n"
# b"'BUS_887_EGNC_FSE'\n"
# b"'BUS_887_EGSU_FSE'\n"
# b"'BUS_901_EGDK_Sales Management'\n"
# b"'BUS_901_EGNC_Sales Management'\n"
# b"'BUS_901_EGSU_Sales Management'\n"
# b"'BUS_901_EXDK_Sales Management'\n"
# b"'BUS_901_EXNO_Sales Management'\n"
# b"'BUS_901_EXSE_Sales Management'\n"
# b"'BUS_902_EGDK_Sales Service'\n"
# b"'BUS_902_EGNC_Sales service'\n"
# b"'BUS_902_EGSU_Sales Service'\n"
# b"'BUS_902_EXDK_Sales Service'\n"
# b"'BUS_902_EXNO_Sales Service'\n"
# b"'BUS_902_EXSE_Sales Service'\n"
# b"'BUS_911_EGDK_Bid Management'\n"
# b"'BUS_911_EGNC_Bid Management'\n"
# b"'BUS_911_EGSU_Bid Management'\n"
# b"'BUS_911_EXDK_Bid Management'\n"
# b"'BUS_911_EXNO_Bid Management'\n"
# b"'BUS_912_EGDK_Sales Transportation & Services'\n"
# b"'BUS_912_EGGL_Sales Transportation & Services'\n"
# b"'BUS_912_EGNC_Sales Transportation & Services'\n"
# b"'BUS_912_EXDK_Sales Transportation & Services'\n"
# b"'BUS_912_EXNO_Sales Transportation & Services'\n"
# b"'BUS_931_EGDK_Microsoft license Sales'\n"
# b"'BUS_931_EXDK_Microsoft license Sales'\n"
# b"'BUS_932_EGDK_Digital Solutions Sales'\n"
# b"'BUS_932_EGNC_Digital Solutions Sales'\n"
# b"'BUS_932_EGSU_Digital Solutions Sales'\n"
# b"'BUS_932_EXDK_Digital Solutions Sales'\n"
# b"'BUS_932_EXNO_Digital Solutions Sales'\n"
# b"'BUS_932_EXSE_Digital Solutions Sales'\n"
# b"'BUS_960_EGSU_EG Dynamics (Medius)'\n"
# b"'BUS_997_EGDK_Capex'\n"
# b"'BUS_997_EGNC_Capex'\n"
# b"'BUS_997_EGSU_Capex'\n"
# b"'BUS_999_EGDK_Strategiske initiativer'\n"
# b"'BUS_999_EGNC_Strategiske initiativer'\n"
# b"'BUS_999_EGSU_Strategiske initiativer'\n"
# b"'Business Analytics'\n"
# b"'Business and IT-strategy'\n"
# b"'Business Development'\n"
# b"'Business Excellence'\n"
# b"'Business Intelligence'\n"
# b"'Business Partnering'\n"
# b"'Business Simulation 2016'\n"
# b"'BusinessInsightReporting'\n"
# b"'BWT'\n"
# b"'Byg og Installatin'\n"
# b"'Byg On Tour 2016'\n"
# b"'Bygghemma'\n"
# b"'Byggmax'\n"
# b"'Bygg-Service 030523'\n"
# b"'C&H Cloud Services'\n"
# b"'C&H Delivery'\n"
# b"'C&H Hj\\xc3\\xb8rring'\n"
# b"'C&H Lederm\\xc3\\xb8der'\n"
# b"'C&H Monitorering'\n"
# b"'C&H Technical Security Board'\n"
# b"'Cable Quick'\n"
# b"'Cageball - Oslo'\n"
# b"'cahros store plan'\n"
# b"'Camilla Lisse S\\xc3\\xb8rensen'\n"
# b"'Camilla M\\xc3\\xb8ller Olesen'\n"
# b"'Camilla Ravn'\n"
# b"'Camilla Salimi'\n"
# b"'Camilla Sk\\xc3\\xb8ien Jensen'\n"
# b"'Campaigns & branding'\n"
# b"'Camurus'\n"
# b"'Camurus SCM'\n"
# b"'Camusrus_AX72_PU12'\n"
# b"'Canteen Ballerup'\n"
# b"'Canteen Herning'\n"
# b"'Canteen Hj\\xc3\\xb8rring'\n"
# b"'Canteen Holb\\xc3\\xa6k'\n"
# b"'Canteen Odense'\n"
# b"'Canteen Thisted'\n"
# b"'Capability group'\n"
# b"'Capability Group - Microsoft Dynamics 365 Finance and Operations'\n"
# b"'Capability Group SQL Server'\n"
# b"'Capability Lead'\n"
# b"'Capability Lead - BI'\n"
# b"'Capability Lead - General'\n"
# b"'Capability Lead - SCM'\n"
# b"'Capability Lead Dynamics AX Lessor L\\xc3\\xb8n'\n"
# b"'Capability Leads - AX'\n"
# b"'carePlan Implementering'\n"
# b"'Carina Kvarnl\\xc3\\xb6f'\n"
# b"'Carl Einar Eriksen Jensen'\n"
# b"'Carl Kihlgren'\n"
# b"'Carl Storegaard'\n"
# b"'Carl Terje Lippestad'\n"
# b"'Caroline Helbo Andersen'\n"
# b"'Carsten Alstrup'\n"
# b"'Carsten Binderup'\n"
# b"'Carsten Deleuran Andersen'\n"
# b"'Carsten Fjelstrup'\n"
# b"'Carsten Gether S\\xc3\\xb8rensen'\n"
# b"'Carsten Gydesen'\n"
# b"'Carsten Kj\\xc3\\xa6r Petersen'\n"
# b"'Carsten Mathiassen'\n"
# b"'Carsten Nielsen'\n"
# b"'Carsten Peter Sletting Br\\xc3\\xa6ndgaard'\n"
# b"'Carsten Ren\\xc3\\xa9 Pedersen'\n"
# b"'Carsten Skoven'\n"
# b"'Carsten T. Christensen'\n"
# b"'Carsten Test Team'\n"
# b"'Carsten Tygesen'\n"
# b"'Carsten Vier\\xc3\\xb8'\n"
# b"'Caspar Bergstr\\xc3\\xb8m'\n"
# b"'Caspar Miller'\n"
# b"'Casper M\\xc3\\xb8ller Jensen'\n"
# b"'Casper Otte Larsen'\n"
# b"'Casper Schou Nielsen'\n"
# b"'Cassels'\n"
# b"'CBS Lessor DocShare'\n"
# b"'CCJ - CRM'\n"
# b"'CCVagt'\n"
# b"'CDS-A'\n"
# b"'Cecilie Petersen'\n"
# b"'Cecilie Schmidt Eriksen'\n"
# b"'Celina Bonde Kj\\xc3\\xa6r'\n"
# b"'CEM Rapid implementation metodology'\n"
# b"'CEO update cascadering'\n"
# b"'Cervera'\n"
# b"'Cervera Customer'\n"
# b"'Chanett Christina Bangsted'\n"
# b"'Charlotta Patriksson'\n"
# b"'Charlotte Engberg'\n"
# b"'Charlotte Haunstrup'\n"
# b"'Charlotte Jacobsen'\n"
# b"'Charlotte Kammer Jensen'\n"
# b"'Charlotte Kehlet Godt'\n"
# b"'Charlotte Kronborg Bennetsen'\n"
# b"'Charlotte Littau'\n"
# b"'Charlotte \\xc3\\x98elund Ledersborg'\n"
# b"'Charlotte Reinicke Svendsen'\n"
# b"'Charlotte Skovb\\xc3\\xa6ch Pedersen'\n"
# b"'Charlotte Skr\\xc3\\xa6p'\n"
# b"'Charlotte Thomsen'\n"
# b"'Cheap Monday'\n"
# b"'Chemring Nobel'\n"
# b"'Chemring Nobel'\n"
# b"'Chemring SSA-T'\n"
# b"'Chief Technology Office'\n"
# b"'Choni Mortensen'\n"
# b"'Chris Christiansen'\n"
# b"'Chrisco B2B'\n"
# b"'Christer Bertilsson'\n"
# b"'Christian Bex\\xc3\\xa9us'\n"
# b"'Christian Flyvholm Christensen'\n"
# b"'Christian Gredsted'\n"
# b"'Christian Hansen'\n"
# b"'Christian Jansson'\n"
# b"'Christian Klarskov G\\xc3\\xb8rtz'\n"
# b"'Christian Lenz'\n"
# b"'Christian Lyck Hansen'\n"
# b"'Christian Marcus Larsen'\n"
# b"'Christian Marcus Larsen (ADM)'\n"
# b"'Christian Mulvad'\n"
# b"'Christian Peter Olsen'\n"
# b"'Christian Sand Pilgaard'\n"
# b"'Christian Schreiber'\n"
# b"'Christian Schultz Ottosen'\n"
# b"'Christian Seierstad'\n"
# b"'Christian Syberg Larsen'\n"
# b"'Christina Bj\\xc3\\xb8rk'\n"
# b"'Christina Bock Simonsen'\n"
# b"'Christina Hildebrandt Skuldb\\xc3\\xb8l'\n"
# b"'Christina Kj\\xc3\\xa6r Lund'\n"
# b"'Christina Lyng-Madsen'\n"
# b"'Christina N\\xc3\\xb8rring'\n"
# b"'Christina Sig'\n"
# b"'Christina Stampe Jensen'\n"
# b"'Christoffer \\xc3\\x98stergaard Groot'\n"
# b"'Christopher Grahn'\n"
# b"'Christopher Stadheim'\n"
# b"'CIO-event EG Malm\\xc3\\xb6'\n"
# b"'CIT_DNS admin'\n"
# b"'Claes Jigin'\n"
# b"'Clas Ohlson'\n"
# b"'Claus Andreasen'\n"
# b"'Claus Brink'\n"
# b"'Claus Christensen'\n"
# b"'Claus Hansen'\n"
# b"'Claus Holm Nielsen'\n"
# b"'Claus Jacobsen'\n"
# b"'Claus Kj\\xc3\\xa6r Vinther'\n"
# b"'Claus Kraft'\n"
# b"'Claus Nygaard-Pedersen'\n"
# b"'Claus Rasmussen'\n"
# b"'Claus Steffensen'\n"
# b"'Claus Tangsgaard'\n"
# b"'Claus Trillingsgaard'\n"
# b"'Clayton Loden'\n"
# b"'Clinea med Brandsoft regnskab'\n"
# b"'Clinea Storkunde site'\n"
# b"'ClinicCare'\n"
# b"'Cloud Delivery'\n"
# b"'Cloud Delivery'\n"
# b"'Cloud Forum'\n"
# b"'Cloud in C&H'\n"
# b"'Cloud og Hosting'\n"
# b"'Cloud Technicians'\n"
# b"'Cluster 3 task force'\n"
# b"'CMS projekt'\n"
# b"'Code issues'\n"
# b"'Cognos Teknik'\n"
# b"'Cognos users'\n"
# b"'Comfort'\n"
# b"'Comfort POC'\n"
# b"'Comfort-Kedjan Betalningsansvar'\n"
# b"'Communications & Content at EG'\n"
# b"'Community Work'\n"
# b"'Company of Adventurers'\n"
# b"'Connect 360 Development'\n"
# b"'Connie Kristensen'\n"
# b"'Conny Gyllander'\n"
# b"'Conny Jensen'\n"
# b"'Conscia'\n"
# b"'Consignor'\n"
# b"'Consultancy'\n"
# b"'Content'\n"
# b"'Content team'\n"
# b"'Convergence 2015'\n"
# b"'Coop Nord'\n"
# b"'CORO planning'\n"
# b"'COROEG'\n"
# b"'Corporate Management'\n"
# b"'Corporate Support'\n"
# b"'CORVUS - Intern'\n"
# b"'CostBar Bestyrelse'\n"
# b"'CPH'\n"
# b"'CRM'\n"
# b"'CRM & SharePoint'\n"
# b"'CRM Demo BI'\n"
# b"'CRM Graduates'\n"
# b"'CRM Sweden'\n"
# b"'CRMTest'\n"
# b"'Cross Norge'\n"
# b"'CrossWork 2016 - Process Control'\n"
# b"'CrossWork den gode historie'\n"
# b"'CrossWork salgsmateriale'\n"
# b"'CrossWork Testsite'\n"
# b"'CrossWork til Modst'\n"
# b"'Cryos'\n"
# b"'CS - all leaders'\n"
# b"'CS - Marketingoverblik'\n"
# b"'CS Bid management'\n"
# b"'CS Business Cases'\n"
# b"'CS Cognos Support'\n"
# b"'CS contracts'\n"
# b"'CS Field Service Dispatch'\n"
# b"'CS IMS'\n"
# b"'CS ledelsen'\n"
# b"'CS Management'\n"
# b"'CS Management team'\n"
# b"'CS Salg Ledelse'\n"
# b"'CS udbuds-pipeline'\n"
# b"'CS-Infrastruktur'\n"
# b"'CSP - Customer Satisfaction Program'\n"
# b"'CST Zynergy'\n"
# b"'CST Zynergy Application Management'\n"
# b"'cstsupport'\n"
# b"'CTO Mgmt Team'\n"
# b"'Customer list - segmentering'\n"
# b"'Customer Support'\n"
# b"'Customer Transison to Hosting'\n"
# b"'CV@ctek.dk'\n"
# b"'CW - intern pr\\xc3\\xa6sentation 280219'\n"
# b"'CWSupport'\n"
# b"'Cwtest'\n"
# b"'Cyprian Kwaczy\\xc5\\x84ski'\n"
# b"'D365'\n"
# b"'D365 - Vertical Solutions - packaging'\n"
# b"'D365 Ler\\xc3\\xb8y Internal'\n"
# b"'D365 PS and Retail Demo'\n"
# b"'D365 Retail POS'\n"
# b"'D365 Standard Data Package Project'\n"
# b"'D365 Tips & Trix'\n"
# b"'D365 Utility Dagarna 2017'\n"
# b"'D365 weekend in Poland 2018'\n"
# b"'D365_Demo'\n"
# b"'D365EG Retail Training'\n"
# b"'D365FO - Lyse'\n"
# b"'D365FO Test Automation'\n"
# b"'da_support@eg.dk'\n"
# b"'Dag Lindahl'\n"
# b"'Dag Martin Rosbach'\n"
# b"'Dag-Andre Lundeby'\n"
# b"'Dagligt Scrum m\\xc3\\xb8de for Koordination af opgaver'\n"
# b"'Daily tasks'\n"
# b"'Dan Halager Nielsen'\n"
# b"'Dan Lundstr\\xc3\\xb6m'\n"
# b"'Dan Madsen'\n"
# b"'Dan Steg'\n"
# b"'Dancenter'\n"
# b"'Daniel Bendixen'\n"
# b"'Daniel Dziubecki'\n"
# b"'Daniel Emil Andersen'\n"
# b"'Daniel Hammarin'\n"
# b"'Daniel Heder'\n"
# b"'Daniel Henningsver'\n"
# b"'Daniel Hindemith'\n"
# b"'Daniel Quist'\n"
# b"'Dann Olsen'\n"
# b"'Dann S\\xc3\\xb8jberg'\n"
# b"'Dannevirke'\n"
# b"'Dansk Erhverv'\n"
# b"'Dariusz Durka'\n"
# b"'Dariusz Pasturczak'\n"
# b"'Dariusz Pawlukiewicz'\n"
# b"'Dariusz Wieckowski'\n"
# b"'DAT207x'\n"
# b"'DAT207xVA'\n"
# b"'Data'\n"
# b"'Databasesikkerhed - brugere og roller'\n"
# b"'Databehandleraftaler'\n"
# b"'DataflowTest'\n"
# b"'Datawarehouse arkitektur'\n"
# b"'Datta Ankushe'\n"
# b"'David Bergling'\n"
# b"'David Buhauer'\n"
# b"'David Eskilsson'\n"
# b"'david kristensson'\n"
# b"'Dawid Kaczmarek'\n"
# b"'DAX utbildning'\n"
# b"'DC01 - Oml\\xc3\\xa6gningsprojekt'\n"
# b"'DE og SD Konsulent'\n"
# b"'De Unges Klub'\n"
# b"'Debitor - Status Inddrivelse fortrinsberettigede krav opgavemr 00705842'\n"
# b"'Deep G'\n"
# b"'Delivery'\n"
# b"'Delivery Management'\n"
# b"'delve'\n"
# b"'delve.office.com'\n"
# b"'Demo BI Norge'\n"
# b"'Demo Microsoft Teams'\n"
# b"'demogroup'\n"
# b"'Dennis Antonijevic'\n"
# b"'Dennis Boutrup'\n"
# b"'Dennis Jon Rostrup'\n"
# b"'Dep 426 leder'\n"
# b"'Dep 495'\n"
# b"'DEP 495'\n"
# b"'DEP 582'\n"
# b"'Dep 582 - Leveranse'\n"
# b"'DEP 583 Kampanjer'\n"
# b"'DEP 584'\n"
# b"'Dep. 424 ledergruppe'\n"
# b"'DEP_001_EGDK_Koncernen'\n"
# b"'DEP_001_EGNC_Koncernen'\n"
# b"'DEP_001_EGSD_Koncernen'\n"
# b"'DEP_001_EGSU_Koncernen'\n"
# b"'DEP_001_EGTO_Koncernen'\n"
# b"'DEP_001_PUBL_Koncernen'\n"
# b"'DEP_002_EGDK_Marketing and Communications'\n"
# b"'DEP_002_EGNC_Marketing planning'\n"
# b"'DEP_002_EGTO_Marketing planning'\n"
# b"'DEP_004_EGDK_EG Holding'\n"
# b"'DEP_005_EGDK_IT Project Management'\n"
# b"'DEP_006_EGDK_Buffer'\n"
# b"'DEP_007_EGDK_IT Governance'\n"
# b"'DEP_008_EGDK_IT Infrastructure'\n"
# b"'DEP_008_EGSU_IT Infrastructure'\n"
# b"'DEP_009_EGDK_IT Operations'\n"
# b"'DEP_010_EGDK_IT Management'\n"
# b"'DEP_010_EGNC_IT Management'\n"
# b"'DEP_011_EGDK_IT Services'\n"
# b"'DEP_015_DYNA_Procurement'\n"
# b"'DEP_015_EGDK_Procurement'\n"
# b"'DEP_015_EGEM_Procurement'\n"
# b"'DEP_015_EGNC_Procurement'\n"
# b"'DEP_015_EGSD_Procurement'\n"
# b"'DEP_015_EGSU_Procurement'\n"
# b"'DEP_015_EGTO_Procurement'\n"
# b"'DEP_015_PUBL_Procurement'\n"
# b"'DEP_030_EGDK_CS/BRS/utility execution'\n"
# b"'DEP_031_EGDK_VBS execution'\n"
# b"'DEP_032_EGDK_Analytics & Applications'\n"
# b"'DEP_033_EGDK_Content and Communications'\n"
# b"'DEP_033_EGNC_Communications'\n"
# b"'DEP_033_EGSU_Communications'\n"
# b"'DEP_034_EGDK_Applications'\n"
# b"'DEP_061_EGDK_Facility, Property'\n"
# b"'DEP_061_EGEM_Facility, Property'\n"
# b"'DEP_061_EGNC_Facility, Property'\n"
# b"'DEP_061_EGSD_Facility, Property'\n"
# b"'DEP_061_EGSU_Facility, Property'\n"
# b"'DEP_061_EGTO_Facility, Property'\n"
# b"'DEP_061_PUBL_Facility, Property'\n"
# b"'DEP_062_EGTO_Administration 2'\n"
# b"'DEP_063_EGDK_Facility, Canteen'\n"
# b"'DEP_063_EGNC_Facility, Canteen'\n"
# b"'DEP_063_EGSD_Facility, Canteen'\n"
# b"'DEP_063_EGSU_Facility, Canteen'\n"
# b"'DEP_067_EGDK_Administration, Service'\n"
# b"'DEP_067_EGNC_Administration, Service'\n"
# b"'DEP_067_EGSU_Administration, Service'\n"
# b"'DEP_067_EGTO_Administration, Service'\n"
# b"'DEP_068_EGDK_F\\xc3\\xa6lleshuset'\n"
# b"'DEP_070_EGDK_Business Finance Development'\n"
# b"'DEP_071_EGDK_Finance'\n"
# b"'DEP_071_EGGL_Finance'\n"
# b"'DEP_071_EGNC_Finance'\n"
# b"'DEP_071_EGSU_Finance'\n"
# b"'DEP_071_EGTO_Finance'\n"
# b"'DEP_072_DYNA_Group Controlling'\n"
# b"'DEP_072_EGDK_Group Controlling'\n"
# b"'DEP_072_EGEM_Group Controlling'\n"
# b"'DEP_072_EGGL_Group Controlling'\n"
# b"'DEP_072_EGNC_Controlling'\n"
# b"'DEP_072_EGSU_Controlling'\n"
# b"'DEP_072_EGTO_Group Controlling'\n"
# b"'DEP_072_PUBL_Group Controlling'\n"
# b"'DEP_075_EGDK_Analytics'\n"
# b"'DEP_075_EGNC_Analytics'\n"
# b"'DEP_075_EGSU_Analytics'\n"
# b"'DEP_076_EGDK_PMO Projects'\n"
# b"'DEP_077_EGDK_Financial Planning and Analysis'\n"
# b"'DEP_078_EGDK_GDPR'\n"
# b"'DEP_078_EGNC_GDPR'\n"
# b"'DEP_079_EGDK_Business Partnering'\n"
# b"'DEP_079_EGSU_Business Partnering'\n"
# b"'DEP_081_EGDK_Human Resource'\n"
# b"'DEP_081_EGNC_Human Resource'\n"
# b"'DEP_081_EGSU_Human Resource'\n"
# b"'DEP_087_EGDK_FGROUP'\n"
# b"'DEP_087_EGNC_FGROUP'\n"
# b"'DEP_087_EGSU_FGROUP'\n"
# b"'DEP_092_EGDK_Leasing IFRS 16'\n"
# b"'DEP_093_DYNA_Overhead'\n"
# b"'DEP_093_EGDK_Overhead'\n"
# b"'DEP_093_EGNC_Overhead'\n"
# b"'DEP_093_EGSD_Overhead'\n"
# b"'DEP_093_EGSU_Overhead'\n"
# b"'DEP_093_EGTO_Overhead'\n"
# b"'DEP_093_PUBL_Overhead'\n"
# b"'DEP_095_EGDK_Corp PMO'\n"
# b"'DEP_097_EGDK_EG Management Consulting & Process Management Office'\n"
# b"'DEP_099_EGDK_Global Delivery'\n"
# b"'DEP_100_EGDK_EG Bolig Konsulenter'\n"
# b"'DEP_101_EGDK_Operations Management'\n"
# b"'DEP_101_EGNC_Operations Management'\n"
# b"'DEP_107_EGDK_ASPECT4 Foundation Logistik'\n"
# b"'DEP_111_EGDK_Finance & Administration'\n"
# b"'DEP_145_EGDK_ASPECT4 \\xc3\\x98ko'\n"
# b"'DEP_148_EGDK_ASPECT4 Foundation'\n"
# b"'DEP_151_EGDK_Human Resource'\n"
# b"'DEP_151_EGNC_Human Resource'\n"
# b"'DEP_151_EGSU_Human Resource'\n"
# b"'DEP_151_EXDK_Human Resource'\n"
# b"'DEP_151_EXNO_Human Resource'\n"
# b"'DEP_151_EXSE_Human Resource'\n"
# b"'DEP_152_EGDK_PMO'\n"
# b"'DEP_152_EXDK_PMO'\n"
# b"'DEP_153_EXDK_IT Operations'\n"
# b"'DEP_153_EXNO_IT Operations'\n"
# b"'DEP_153_EXSE_IT Operations'\n"
# b"'DEP_154_EXDK_Overhead'\n"
# b"'DEP_154_EXNO_Overhead'\n"
# b"'DEP_154_EXSE_Overhead'\n"
# b"'DEP_155_EGDK_Service overhead'\n"
# b"'DEP_155_EGNC_Service overhead'\n"
# b"'DEP_155_EGSU_Service overhead'\n"
# b"'DEP_160_EGDK_Content and Communications'\n"
# b"'DEP_160_EGNC_Content and Communications'\n"
# b"'DEP_160_EXDK_Content and Communications'\n"
# b"'DEP_160_EXNO_Content and Communications'\n"
# b"'DEP_161_EGDK_Analytics & Applications'\n"
# b"'DEP_161_EXDK_Analytics & Applications'\n"
# b"'DEP_162_EGDK_VBS execution'\n"
# b"'DEP_162_EXDK_VBS execution'\n"
# b"'DEP_163_EGDK_Service design & Technology Innovation'\n"
# b"'DEP_163_EXDK_Service design & Technology Innovation'\n"
# b"'DEP_164_EGDK_CS/BRS/utility execution'\n"
# b"'DEP_164_EXDK_CS/BRS/utility execution'\n"
# b"'DEP_165_EGDK_Marketing and Communications'\n"
# b"'DEP_165_EXDK_Marketing and Communications'\n"
# b"'DEP_167_EGDK_Business Partnering'\n"
# b"'DEP_167_EGSU_Business Partnering'\n"
# b"'DEP_167_EXDK_Business Partnering'\n"
# b"'DEP_168_EGDK_Finance'\n"
# b"'DEP_168_EXDK_Finance'\n"
# b"'DEP_168_EXNO_Finance'\n"
# b"'DEP_168_EXSE_Finance'\n"
# b"'DEP_169_EGDK_Group Controlling'\n"
# b"'DEP_169_EXDK_Group Controlling'\n"
# b"'DEP_201_EGDK_Business Development'\n"
# b"'DEP_206_EGDK_ASPECT4 Management'\n"
# b"'DEP_208_EGDK_ASPECT4 Fashion'\n"
# b"'DEP_211_EGDK_Business Development'\n"
# b"'DEP_213_EGDK_ASPECT4 Logistik'\n"
# b"'DEP_217_EGDK_ASPECT4 HR'\n"
# ...
# b"'USR_EGU_CS_Utveckling'\n"
# b"'USR_EGU_DIV_300_Utility'\n"
# b"'USR_EGU_GLT'\n"
# b"'USR_EGU_Hotline'\n"
# b"'USR_EGU_IT Teknik'\n"
# b"'USR_EGU_Konsulenter'\n"
# b"'USR_EGU_Kundeservice'\n"
# b"'USR_EGU_Ledere'\n"
# b"'USR_EGU_Malm\\xc3\\xb8'\n"
# b"'USR_EGU_M\\xc3\\xb8lndal'\n"
# b"'USR_EGU_NO_EG Utility Alle'\n"
# b"'USR_EGU_\\xc3\\x96rebro'\n"
# b"'USR_EGU_\\xc3\\x96stersund'\n"
# b"'USR_EGU_S\\xc3\\xa6lgere i Norden'\n"
# b"'USR_EGU_Salgsafdeling'\n"
# b"'USR_EGU_Stockholm'\n"
# b"'USR_EGU_Technology Team DK'\n"
# b"'USR_EGU_Technology Team Global'\n"
# b"'USR_EGU_Udviklere'\n"
# b"'USR_EGU_Udviklere \\xc3\\x85rhus'\n"
# b"'USR_EGU_Udviklere Hj\\xc3\\xb8rring'\n"
# b"'USR_EGU_Xellent'\n"
# b"'USR_EGX_bestyrelse'\n"
# b"'USR_Enterprise_All'\n"
# b"'USR_Enterprise_DK'\n"
# b"'usr_erkra_test_dist'\n"
# b"'USR_ERP_Superusers'\n"
# b"'USR_Everyone in Sweden, Eskilstuna'\n"
# b"'USR_Fakturalayout'\n"
# b"'USR_Finance'\n"
# b"'USR_FINANCE_Debitor'\n"
# b"'USR_FINANCE_Fakturering'\n"
# b"'USR_FINANCE_Kreditor'\n"
# b"'USR_FINANCE_Likviditet'\n"
# b"'USR_FINANCE_L\\xc3\\xb8n'\n"
# b"'USR_Finance-Boghold'\n"
# b"'USR_Financial Performance Management'\n"
# b"'USR_Funktionelle-Teams'\n"
# b"'USR_GC_Alerts'\n"
# b"'USR_Graduates_2015'\n"
# b"'USR_Graduates_2016'\n"
# b"'USR_Hairtools_AutoBug'\n"
# b"'USR_Hairtools_Drift'\n"
# b"'USR_Hairtools_Kundeteam'\n"
# b"'USR_Hairtools_Salg'\n"
# b"'USR_Hairtools_Scrummaster'\n"
# b"'USR_Hairtools_Service'\n"
# b"'USR_Hairtools_Tech'\n"
# b"'USR_Hairtools_Udvikling'\n"
# b"'USR_Healthcare_Dansk R\\xc3\\xb8de Kors'\n"
# b"'USR_Healthcare_Region Midt Support Distribution'\n"
# b"'USR_Healthcare_Support_Group'\n"
# b"'USR_Healthcare_Vejle Sygehus'\n"
# b"'USR_Healthcarer_SMTP'\n"
# b"'USR_HERSEGIT01_PMO_Admin_Members'\n"
# b"'USR_HERSEGIT01_PMO_Members'\n"
# b"'USR_HERSEGIT01_PMO_WiP_PMM_Visitors'\n"
# b"'USR_HR_Manager Handbook'\n"
# b"'USR_HR_udsendelseDK'\n"
# b"'USR_IM DK'\n"
# b"'USR_IM SE & NO'\n"
# b"'USR_IM2_DK'\n"
# b"'USR_Intern - HTS'\n"
# b"'USR_Investor'\n"
# b"'USR_JNadvisering'\n"
# b"'USR_Julegave'\n"
# b"'USR_KI-Aarhus Suppor'\n"
# b"'USR_KI-Alle'\n"
# b"'USR_KI-\\xc3\\x85rhus'\n"
# b"'USR_KI-Blanket'\n"
# b"'USR_KI-CP'\n"
# b"'USR_KI-IT'\n"
# b"'USR_KI-K\\xc3\\xb8benhavn'\n"
# b"'USR_KI-Ledelse'\n"
# b"'USR_KI-Markedskonsulenter'\n"
# b"'USR_KI-Marketing'\n"
# b"'USR_KI-PM'\n"
# b"'USR_KI-Produktchefer'\n"
# b"'USR_Ki-scanning'\n"
# b"'USR_KI-workflow'\n"
# b"'USR_KI-XML'\n"
# b"'USR_Klargoering'\n"
# b"'USR_KOM2'\n"
# b"'USR_Kursus'\n"
# b"'USR_KY_Achitecture_Board_DK'\n"
# b"'USR_KY_All_DK'\n"
# b"'USR_KY_Architects_DK'\n"
# b"'USR_KY_Case Worker - India'\n"
# b"'USR_KY_Core'\n"
# b"'USR_KY_Database - India'\n"
# b"'USR_KY_Dev_DK'\n"
# b"'USR_KY_Func_DK'\n"
# b"'USR_KY_GUI - India'\n"
# b"'USR_KY_GUI_DK'\n"
# b"'USR_KY_Installation - India'\n"
# b"'USR_KY_Integration_DK'\n"
# b"'USR_KY_Integrations & Security - India'\n"
# b"'USR_KY_OI_DK'\n"
# b"'USR_KY_Project Management - India'\n"
# b"'USR_KY_Self-Service - India'\n"
# b"'USR_KY_Service_Delivery_DK'\n"
# b"'USR_KY_SPOC_DK'\n"
# b"'USR_KY_System Design - India'\n"
# b"'USR_KY_Test_DK'\n"
# b"'USR_KY_Testing - India'\n"
# b"'USR_KY_UI_DK'\n"
# b"'USR_KY_Use Cases - Inida'\n"
# b"'USR_KY_usecases_DK'\n"
# b"'USR_KY_Workflows - India'\n"
# b"'USR_Ky-Project'\n"
# b"'USR_Lean Ansvarlige'\n"
# b"'USR_Ledere prod.afd'\n"
# b"'USR_Ledergruppen - divisionsdirekt\\xc3\\xb8rerne'\n"
# b"'USR_Ledernetv\\xc3\\xa6rk'\n"
# b"'USR_List_Infrastructure'\n"
# b"'USR_L\\xc3\\xb8n og \\xc3\\x98konomi'\n"
# b"'USR_Magasin/Magasin Projektet'\n"
# b"'USR_Management_CountryManagers'\n"
# b"'USR_Management_Division'\n"
# b"'USR_Management_Top'\n"
# b"'USR_Manufacturing and Construction_DK'\n"
# b"'USR_Marketing_kampagner'\n"
# b"'USR_Marketing_Norge'\n"
# b"'USR_Marketing_Online & Automation'\n"
# b"'USR_Marketing_partner'\n"
# b"'USR_MFsupport'\n"
# b"'USR_MS_Partner_Source'\n"
# b"'USR_Naviel'\n"
# b"'USR_NAVUDV'\n"
# b"'USR_Norge Tr\\xc3\\xa6last'\n"
# b"'USR_Notes kompetencegruppe'\n"
# b"'USR_O365_DLP-test'\n"
# b"'USR_OS_Indsigt_Udvikler'\n"
# b"'USR_\\xc3\\x98S2000 Distribution'\n"
# b"'USR_\\xc3\\x98S2000 Drift'\n"
# b"'USR_Pandora'\n"
# b"'USR_PD_Crosswork'\n"
# b"'USR_PD_EGVI'\n"
# b"'USR_PD_HC'\n"
# b"'USR_PD_PI'\n"
# b"'USR_PD_PP'\n"
# b"'USR_Personaleforening \\xc3\\x85rhus'\n"
# b"'USR_Personalforening Ballerup'\n"
# b"'USR_Plandent_Projekt'\n"
# b"'USR_PMO_DK'\n"
# b"'USR_Powerpoint'\n"
# b"'USR_Product Development Managers'\n"
# b"'USR_Professional Services_Alle'\n"
# b"'USR_Professional Services_alle Aarhus'\n"
# b"'USR_Professional Services_alle Ballerup'\n"
# b"'USR_Professional Services_alle Herning'\n"
# b"'USR_Professional Services_alle Hj\\xc3\\xb8rring'\n"
# b"'USR_Project_Managers_AX_Service_Line'\n"
# b"'USR_Projekt CS'\n"
# b"'USR_Projektledere'\n"
# b"'USR_Psam-ordre'\n"
# b"'USR_Receptionister'\n"
# b"'USR_Ressourceadministratorer'\n"
# b"'USR_Retail'\n"
# b"'USR_Retail and distribution_DK'\n"
# b"'USR_Retail Malm\\xc3\\xb6'\n"
# b"'USR_Retail_DK_Ledelse'\n"
# b"'USR_SalesInsight_SSIS_notifications'\n"
# b"'USR_SAP-Graduates'\n"
# b"'USR_SD_Adgange og Web'\n"
# b"'USR_SD_Alle'\n"
# b"'USR_SD_Arkitektteamet'\n"
# b"'USR_SD_Arkitekturnetv\\xc3\\xa6rket'\n"
# b"'USR_SD_Bestyrelse'\n"
# b"'USR_SD_CAB'\n"
# b"'USR_SD_Datawarehouse_k\\xc3\\xb8rsel'\n"
# b"'USR_SD_DriftInfra Support og Forv'\n"
# b"'USR_SD_DriftInfra Udvikling'\n"
# b"'USR_SD_Ekstern konsulenter'\n"
# b"'USR_SD_fagansvarlige'\n"
# b"'USR_SD_Forretningssupport'\n"
# b"'USR_SD_Forretningsudvikling'\n"
# b"'USR_SD_Gazellerne'\n"
# b"'USR_SD_Geparderne'\n"
# b"'USR_SD_HR_Payroll_Dagpenge'\n"
# b"'USR_SD_HR_Payroll_DK'\n"
# b"'USR_SD_HR_Payroll_EG_SD_L\\xc3\\x98N_DK'\n"
# b"'USR_SD_HR_Payroll_L\\xc3\\xb8n'\n"
# b"'USR_SD_HR_Payroll_Managament'\n"
# b"'USR_SD_HR_Payroll_Mobil'\n"
# b"'USR_SD_HR_Payroll_Offshore'\n"
# b"'USR_SD_HR_Payroll_Tid'\n"
# b"'USR_SD_HR_Service_Solutions'\n"
# b"'USR_SD_Impl. udd og kons.ydelser - IUK'\n"
# b"'USR_SD_Implementering'\n"
# b"'USR_SD_Inddata'\n"
# b"'USR_SD_Info nyt SD_projekt'\n"
# b"'USR_SD_Inputtot'\n"
# b"'USR_SD_IT Infrastrukturservice'\n"
# b"'USR_SD_Jaguarerne'\n"
# b"'USR_SD_JavaGroup DK'\n"
# b"'USR_SD_JavaGroup India'\n"
# b"'USR_SD_JavaGroup Poland'\n"
# b"'USR_SD_JavaGroup-All'\n"
# b"'USR_SD_Konceptansvar'\n"
# b"'USR_SD_Konstrukt\\xc3\\xb8rer'\n"
# b"'USR_SD_Konverteringsteam'\n"
# b"'USR_SD_KS Projektinddragelse'\n"
# b"'USR_SD_KS Teamledere'\n"
# b"'USR_SD_Kundeservice'\n"
# b"'USR_SD_Lederteam'\n"
# b"'USR_SD_Leoparderne'\n"
# b"'USR_SD_L\\xc3\\xb8n og Overenskomst'\n"
# b"'USR_SD_Losserne'\n"
# b"'USR_SD_\\xc3\\x98konomi og Statistik'\n"
# b"'USR_SD_Payroll_All'\n"
# b"'USR_SD_Payroll_Ledelse'\n"
# b"'USR_SD_Payroll_L\\xc3\\xb8n'\n"
# b"'USR_SD_Payroll_Tid'\n"
# b"'USR_SD_Personale og Organisation'\n"
# b"'USR_SD_Personaleledere'\n"
# b"'USR_SD_PM sager'\n"
# b"'USR_SD_Polen'\n"
# b"'USR_SD_Proces og Metode'\n"
# b"'USR_SD_Produktforvaltning'\n"
# b"'USR_SD_Produktforvaltning \\xe2\\x80\\x93 Konsulenter'\n"
# b"'USR_SD_Produktionsplanl\\xc3\\xa6gning'\n"
# b"'USR_SD_Produktudvikling'\n"
# b"'USR_SD_Projekt Forretnings Ansvarlige PFA'\n"
# b"'USR_SD_Projektinfo'\n"
# b"'USR_SD_Projektledere'\n"
# b"'USR_SD_PU-Ledelsen'\n"
# b"'USR_SD_PU-LONBOGH'\n"
# b"'USR_SD_Pumaerne'\n"
# b"'USR_SD_PU-Teamledere'\n"
# b"'USR_SD_Ressourcestyring'\n"
# b"'USR_SD_Salg og kundeansvar'\n"
# b"'USR_SD_SD-WEB_Vagt'\n"
# b"'USR_SD_Straksrapport'\n"
# b"'USR_SD_Support og kommunikation'\n"
# b"'USR_SD_Supportteam'\n"
# b"'USR_SD_Teknologi og Infrastruktur'\n"
# b"'USR_SD_Telefon-\\xc3\\x98'\n"
# b"'USR_SD_Tidsregistrering'\n"
# b"'USR_SD_Tigerne'\n"
# b"'USR_SD_Udbud Ted-Alert'\n"
# b"'USR_SD_Uddata'\n"
# b"'USR_SD_Udvidet ledergruppe'\n"
# b"'USR_SD_vagter'\n"
# b"'USR_SD_Virksomheder og Institutioner'\n"
# b"'USR_SD_WAS Afvikling'\n"
# b"'USR_SD_WAS Arkitekter'\n"
# b"'USR_SD_WAS Project'\n"
# b"'USR_SD_WAS Quick Migration'\n"
# b"'USR_SD_WCM Brugere'\n"
# b"'USR_SD_Web forvaltning'\n"
# b"'USR_SDC'\n"
# b"'USR_SDMailboxFullAccess'\n"
# b"'USR_SE_AX_Support'\n"
# b"'USR_SE_Events'\n"
# b"'USR_SecureAware_SPO_SiteOwners'\n"
# b"'USR_Segment Norge'\n"
# b"'USR_Sekret\\xc3\\xa6rer'\n"
# b"'USR_Selskabsdirekt\\xc3\\xb8rer'\n"
# b"'USR_Serviceaction_admaal'\n"
# b"'USR_Serviceaction_admarh'\n"
# b"'USR_Serviceaction_admbal'\n"
# b"'USR_Serviceaction_admber'\n"
# b"'USR_Serviceaction_admdal'\n"
# b"'USR_Serviceaction_admesk'\n"
# b"'USR_Serviceaction_admgjo'\n"
# b"'USR_Serviceaction_admgot'\n"
# b"'USR_Serviceaction_admher'\n"
# b"'USR_Serviceaction_admhjo'\n"
# b"'USR_Serviceaction_admhol'\n"
# b"'USR_Serviceaction_admkbh'\n"
# b"'USR_Serviceaction_admkol'\n"
# b"'USR_Serviceaction_admlin'\n"
# b"'USR_Serviceaction_admmal'\n"
# b"'USR_Serviceaction_admmol'\n"
# b"'USR_Serviceaction_admnuu'\n"
# b"'USR_Serviceaction_admod2'\n"
# b"'USR_Serviceaction_admode'\n"
# b"'USR_Serviceaction_admore'\n"
# b"'USR_Serviceaction_admosl'\n"
# b"'USR_Serviceaction_admost'\n"
# b"'USR_Serviceaction_admsan'\n"
# b"'USR_Serviceaction_admsas'\n"
# b"'USR_Serviceaction_admsil'\n"
# b"'USR_Serviceaction_admsto'\n"
# b"'USR_Serviceaction_admthi'\n"
# b"'USR_Serviceaction_admtro'\n"
# b"'USR_Serviceaction_admvej'\n"
# b"'USR_ServiceAction_AX_dimension'\n"
# b"'USR_Serviceaction_debitor'\n"
# b"'USR_Serviceaction_debitor_DXC'\n"
# b"'USR_ServiceAction_Fakturalayout'\n"
# b"'USR_Serviceaction_fakturering'\n"
# b"'USR_ServiceAction_HR'\n"
# b"'USR_Serviceaction_kreditor'\n"
# b"'USR_Serviceaction_lonnings'\n"
# b"'USR_Serviceaction_lonnings_norge'\n"
# b"'USR_Serviceaction_lonnings_sverige'\n"
# b"'USR_Serviceaction_sekretariat'\n"
# b"'USR_ServiceAction_Servicedesk'\n"
# b"'usr_serviceaction_test'\n"
# b"'USR_ServiceAction_Webmaster'\n"
# b"'USR_Spinning Ballerup'\n"
# b"'USR_SR_HR_Payroll_Arbejdstidsplaner'\n"
# b"'USR_SR_HR_Payroll_Overenskomst'\n"
# b"'USR_SR_HR_Payroll_personale'\n"
# b"'USR_staffaction_admaal'\n"
# b"'USR_staffaction_admarh'\n"
# b"'USR_staffaction_admbal'\n"
# b"'USR_Staffaction_admber'\n"
# b"'USR_Staffaction_admdal'\n"
# b"'USR_Staffaction_admesk'\n"
# b"'USR_Staffaction_admgjo'\n"
# b"'USR_Staffaction_admgot'\n"
# b"'USR_staffaction_admher'\n"
# b"'USR_staffaction_admhjo'\n"
# b"'USR_staffaction_admhol'\n"
# b"'USR_staffaction_admkbh'\n"
# b"'USR_staffaction_admkol'\n"
# b"'USR_Staffaction_admlin'\n"
# b"'USR_staffaction_admmal'\n"
# b"'USR_staffaction_admmol'\n"
# b"'USR_staffaction_admneokol'\n"
# b"'USR_Staffaction_admnuu'\n"
# b"'USR_Staffaction_admod2'\n"
# b"'USR_staffaction_admode'\n"
# b"'USR_staffaction_admore'\n"
# b"'USR_Staffaction_admosl'\n"
# b"'USR_staffaction_admost'\n"
# b"'USR_staffaction_admsan'\n"
# b"'USR_staffaction_admsas'\n"
# b"'USR_Staffaction_admsil'\n"
# b"'USR_staffaction_admsto'\n"
# b"'USR_staffaction_admthi'\n"
# b"'USR_staffaction_admtro'\n"
# b"'USR_Staffaction_admvej'\n"
# b"'USR_Staffaction_Controllers'\n"
# b"'USR_staffaction_EG_Access'\n"
# b"'USR_staffaction_egdi_servicedesk'\n"
# b"'USR_Staffaction_fakturering'\n"
# b"'USR_StaffAction_HR'\n"
# b"'USR_StaffAction_HR_Recruitment'\n"
# b"'USR_StaffAction_HR_Recruitment_DXC'\n"
# b"'USR_staffaction_kreditor'\n"
# b"'USR_staffaction_lonnings'\n"
# b"'USR_staffaction_lonnings_DXC'\n"
# b"'USR_Staffaction_lonnings_norge'\n"
# b"'USR_staffaction_lonnings_norge_DXC'\n"
# b"'USR_Staffaction_lonnings_sverige'\n"
# b"'USR_staffaction_lonnings_sverige_DXC'\n"
# b"'USR_Staffaction_NeoBrobizz'\n"
# b"'USR_StaffAction_Servicedesk'\n"
# b"'USR_staffaction_telefoniadministration'\n"
# b"'USR_Strategi og Ledelse'\n"
# b"'USR_Superbrugere'\n"
# b"'USR_Support NAV Sweden'\n"
# b"'USR_Target'\n"
# b"'USR_Team Hydra'\n"
# b"'usr_team_145_aspect4_foundation'\n"
# b"'usr_team_148_aspect4_foundation'\n"
# b"'usr_team_217_aspect4_foundation'\n"
# b"'USR_Team_BIDW_Payroll'\n"
# b"'USR_Team_Infrastruktur_Mainframe_Payroll'\n"
# b"'USR_Team_KY'\n"
# b"'USR_Team_TOD_Payroll'\n"
# b"'USR_Teamledere'\n"
# b"'USR_Technology & Delivery Management'\n"
# b"'USR_Technology & Delivery mellemledere'\n"
# b"'USR_Technology_Delivery_Thisted'\n"
# b"'USR_Tekstil - ASPECT/4'\n"
# b"'USR_Tekstil Skandinavien'\n"
# b"'USR_Telefon'\n"
# b"'usr_Telefon Backup'\n"
# b"'USR_Test af PC opdateringer'\n"
# b"'USR_Testscsm_SMBX_FA'\n"
# b"'USR_TFSTeam'\n"
# b"'USR_Thy-data brugere'\n"
# b"'USR_Thydata_DEP_533 Service Solution Medarbejder'\n"
# b"'USR_Topledere'\n"
# b"'USR_Tr\\xc3\\xa6last Skandinavien'\n"
# b"'USR_Udviklercafe - \\xc3\\x85rhus'\n"
# b"'USR_Udviklercafe - Ballerup'\n"
# b"'USR_Udviklercafe - Herning'\n"
# b"'USR_Udviklercafe - Kolding'\n"
# b"'USR_Unibake_Projekt'\n"
# b"'USR_VBS_Project_Managers'\n"
# b"'USR_VBS_Sales_Marketing'\n"
# b"'USR_VIKAN_Projekt'\n"
# b"'USR_Webbased Platforms'\n"
# b"'USR_Webmaster-nordic'\n"
# b"'USR_WINDOWS_UPDATE_TEST_GROUP'\n"
# b"'USR_Wms Brutto'\n"
# b"'USR_Wms Netto'\n"
# b"'USR_Zebra_Team'\n"
# b"'Utility Bid Management'\n"
# b"'Utility Enterprise Solutions'\n"
# b"'Utility Nordic'\n"
# b"'Utility-processer'\n"
# b"'Uttesting av Google desing sprint i web'\n"
# b"'Utveckling'\n"
# b"'Utviklervakt AX'\n"
# b"'Utvikling, Gj\\xc3\\xb8vik'\n"
# b"'UX i EG'\n"
# b"'UX Team'\n"
# b"'UX-afklaringer'\n"
# b"'UX-ugeplan'\n"
# b"'Vagtplanoversigt i SD'\n"
# b"'Vagtplanoversigt til Sydvestjysk Sygehus'\n"
# b"'VamsiKrishna Raghavaiah'\n"
# b"'Varde Kommune'\n"
# b"'Variant & Collaboration 2.0'\n"
# b"'Varner CRM'\n"
# b"'Varner-CRM-Fas3'\n"
# b"'VBS - AX'\n"
# b"'VBS - Managed Services AMS/IMS - steering group'\n"
# b"'VBS Bid Management'\n"
# b"'VBS delivery'\n"
# b"'VBS Inno, Health check as a service'\n"
# b"'VBS Inno: App Source Services'\n"
# b"'VBS Inno: Digital betalingsl\\xc3\\xb8sning (off)'\n"
# b"'VBS Inno: EG Managed Development Team'\n"
# b"'VBS Inno: Sell premium support'\n"
# b"'VBS Marketing'\n"
# b"'VBS Sales - Customer Engagement with D365'\n"
# b"'VBS Sales Management'\n"
# b"'VBS Sales SE'\n"
# b"'VBS SalesManagement'\n"
# b"'VBS Solution Catalogue'\n"
# b"'VBS strategy execution'\n"
# b"'VBS Total Sales'\n"
# b"'VBS/MS/Operations ledergruppe'\n"
# b"'VBS_BCOS Controllergruppe'\n"
# b"'Veidekke - Kontraktsarbeid SSA-T'\n"
# b"'Veidekke ERP besvarelse desember 2017'\n"
# b"'Veidekke_Analyse'\n"
# b"'Velimir Davidovski'\n"
# b"'Venue nya avtal'\n"
# b"'Verdo'\n"
# b"'Verdo slides til Pia'\n"
# b"'Verneombud lokasjon Bergen'\n"
# b"'Verneombud lokasjon Gj\\xc3\\xb8vik'\n"
# b"'Verneombud lokasjon Oslo'\n"
# b"'Verneombud lokasjon Sandefjord'\n"
# b"'Verneombud lokasjon Sandnes'\n"
# b"'Verneombud lokasjon Trondheim'\n"
# b"'Vertical BI'\n"
# b"'Vertical Forum'\n"
# b"'Vertical sales pitches'\n"
# b"'Vertical solutions - Projectoriented Industry (PP)'\n"
# b"'Vertikal Business Solutions AX SE'\n"
# b"'Vertikal overdragelse'\n"
# b"'Vesthimmerland Kommune - Koncernl\\xc3\\xb8sning'\n"
# b"'Vibeke Thyring'\n"
# b"'Victoria Picasso'\n"
# b'"Victoria\'s Workplace"\n'
# b"'Vidinge'\n"
# b"'Vidinge Gr\\xc3\\xb6nt'\n"
# b"'Vigdis Lange Szanto'\n"
# b"'Vignesh Krishna'\n"
# b"'Vignesh Paulraj'\n"
# b"'Vijaykishore.br@sonata-software.com'\n"
# b"'vijaykumar.cn@sonata-software.com'\n"
# b"'Vijhayalekshmi Rajendhirun'\n"
# b"'Vikan Projekt'\n"
# b"'Viken Power BI & GA'\n"
# b"'Viking Outdoor Footwear'\n"
# b"'Viking Outdoor footwear AS'\n"
# b"'Vikrant Vankudre'\n"
# b"'Viktor Ankarberg'\n"
# b"'Viktor Karlsson'\n"
# b"'Villy Gravengaard'\n"
# b"'Visual Code'\n"
# b"'Visual Studio'\n"
# b"'Visualonline@eg.dk'\n"
# b"'Vitaliy Demus'\n"
# b"'Vivi Blaabjerg Rasmussen'\n"
# b"'Vladimir Dzhevalov'\n"
# b"'Vlado Seric'\n"
# b"'Voss Production'\n"
# b"'Vrushali Chaudary'\n"
# b"'VSTS'\n"
# b"'Wabtec (Faiveley)'\n"
# b"'Wallenstam'\n"
# b"'War Room - Trip Route'\n"
# b"'Warsaw, Bolek (14), int'\n"
# b"'Warsaw, Lolek (14), int'\n"
# b"'Warsaw, Reksio (4), int'\n"
# b"'Warsaw, Tola (5), int'\n"
# b"'WarsawTeam'\n"
# b"'Web & Technology'\n"
# b"'Webbased Platforms'\n"
# b"'webmaster-dk'\n"
# b"'webmaster-gl'\n"
# b"'webmaster-no'\n"
# b"'webmaster-se'\n"
# b"'Wenke Eike'\n"
# b"'WhiteAway'\n"
# b"'Wiersholm'\n"
# b"'Win2008 Upgrade'\n"
# b"'Windows 10 Feedback'\n"
# b"'Winnie Jansson'\n"
# b"'Winning Culture'\n"
# b"'Witalis Kinasz'\n"
# b"'WMDPapp_sa'\n"
# b"'WMS'\n"
# b"'Wojciech Mazur'\n"
# b"'Woody'\n"
# b"'Workshop Stockholm'\n"
# b"'Wulff Supplies'\n"
# b"'X'\n"
# b"'X3 Kommunemkonvertering'\n"
# b"'Xellent \\xc3\\xa4rendestatistik'\n"
# b"'Xellent offerings'\n"
# b"'Xellent Product Management'\n"
# b"'Xellent Sweden'\n"
# b"'Xellent2009'\n"
# b"'Xena & Byg'\n"
# b"'Xena Auto'\n"
# b"'Xena support -  zendesk'\n"
# b"'Xena.biz'\n"
# b"'XL-Byg'\n"
# b"'Yammer'\n"
# b"'Yana Maksimova Boozova'\n"
# b"'Yaser Al-Reezalee'\n"
# b"'Yaya Surya Aprilla'\n"
# b"'Yngve Hansen'\n"
# b"'YP Performance Team'\n"
# b"'YR Samarbejde'\n"
# b"'Yrkes Profilkl\\xc3\\xa4der'\n"
# b"'yyhn1'\n"
# b"'yyhn2'\n"
# b"'yysal'\n"
# b"'Zebra'\n"
# b"'Zebra Release Notes'\n"
# b"'Zebra, NETS and EG (Payment)'\n"
# b"'Zoran Boshnjakoski'\n"
# b"'Zynergy'\n"
# b"'Zynergy Management'\n"
# b"'Zynergy PowerBI'\n"
